# %% [markdown]
# # **Homework 2-1 Phoneme Classification**

# %% [markdown]
# ## The DARPA TIMIT Acoustic-Phonetic Continuous Speech Corpus (TIMIT)
# The TIMIT corpus of reading speech has been designed to provide speech data for the acquisition of acoustic-phonetic knowledge and for the development and evaluation of automatic speech recognition systems.
#
# This homework is a multiclass classification task,
# we are going to train a deep neural network classifier to predict the phonemes for each frame from the speech corpus TIMIT.
#
# link: https://academictorrents.com/details/34e2b78745138186976cbc27939b1b34d18bd5b3

# %% [markdown]
# ## Download Data
# Download data from google drive, then unzip it.
#
# You should have `timit_11/train_11.npy`, `timit_11/train_label_11.npy`, and `timit_11/test_11.npy` after running this block.<br><br>
# `timit_11/`
# - `train_11.npy`: training data<br>
# - `train_label_11.npy`: training label<br>
# - `test_11.npy`:  testing data<br><br>
#
# **notes: if the google drive link is dead, you can download the data directly from Kaggle and upload it to the workspace**
# **https://drive.google.com/file/d/1P9RfXu19Equ0VdCs803XGGr8rIIT4XqH/view?usp=sharing**
#
#
# **https://hackmd.io/@lido2370/S1aX6e1nN?type=view**

# %%
from google.colab import drive
drive.mount('/content/drive')
#/content/drive/MyDrive/windows備份/C_Users_Alvin_Documents/~碩班/Course/109-2/機器學習_李宏毅/Week 3/HW2
# Out:
# Mounted at /content/drive

# %%
#!gdown --id '1HPkcmQmFGu-3OknddKIa5dNDsR05lIQR' --output data.zip
# !cp '/content/drive/MyDrive/windows備份/C_Users_Alvin_Documents/~碩班/Course/109-2/機器學習_李宏毅/Week 3/HW2/timit_11_v2.zip' './data.zip'
# !unzip data.zip
# !ls
# Out:
# Archive:  data.zip
#    creating: timit_11/
#   inflating: timit_11/train_11.npy
#   inflating: timit_11/test_11.npy
#   inflating: timit_11/train_label_11.npy
# data.zip  drive  sample_data  timit_11

# %% [markdown]
# ## Preparing Data
# Load the training and testing data from the `.npy` file (NumPy array).

# %%
import numpy as np

print('Loading data ...')

data_root='./timit_11/'
train = np.load(data_root + 'train_11.npy')
train_label = np.load(data_root + 'train_label_11.npy')
test = np.load(data_root + 'test_11.npy')

print('Size of training data: {}'.format(train.shape))
print('Size of testing data: {}'.format(test.shape))
# Out:
# Loading data ...
# Size of training data: (1229932, 429)
# Size of testing data: (451552, 429)

# %%
train_mean = np.mean(train, axis=0, keepdims=True)
train_std = np.std(train, axis=0, keepdims=True)
print('Size of training data mean: {}'.format(train_mean.shape))
print('Size of training data std: {}'.format(train_std.shape))
# Out:
# Size of training data mean: (1, 429)
# Size of training data std: (1, 429)

# %%
# Normalization
# If "train = (train - train_mean) / train_std", memory usage is too large somehow???
train = (train - train_mean)
train = train / train_std
test = (test - train_mean)
test = test / train_std
print('Size of training data after normalization: {}'.format(train.shape))
print('Size of testining data after normalization: {}'.format(test.shape))
import gc
del train_mean, train_std
gc.collect()
# Out:
# Size of training data after normalization: (1229932, 429)
# Size of testining data after normalization: (451552, 429)
# 109

# %% [markdown]
# ## Create Dataset

# %%
import torch
from torch.utils.data import Dataset

class TIMITDataset(Dataset):
    def __init__(self, X, y=None):
        self.data = torch.from_numpy(X).float()
        if y is not None:
            y = y.astype(np.int) # 數據轉換成int
            self.label = torch.LongTensor(y)
        else:
            self.label = None

    def __getitem__(self, idx):
        if self.label is not None:
            return self.data[idx], self.label[idx]
        else:
            return self.data[idx]

    def __len__(self):
        return len(self.data)

# %% [markdown]
# Split the labeled data into a training set and a validation set, you can modify the variable `VAL_RATIO` to change the ratio of validation data.

# %%
VAL_RATIO = 0.1

percent = int(train.shape[0] * (1 - VAL_RATIO))
train_x, train_y, val_x, val_y = train[:percent], train_label[:percent], train[percent:], train_label[percent:]
print('Size of training set: {}'.format(train_x.shape))
print('Size of validation set: {}'.format(val_x.shape))
# Out:
# Size of training set: (1106938, 429)
# Size of validation set: (122994, 429)

# %% [markdown]
# Create a data loader from the dataset, feel free to tweak the variable `BATCH_SIZE` here.

# %%
BATCH_SIZE = 128

from torch.utils.data import DataLoader

train_set = TIMITDataset(train_x, train_y)
val_set = TIMITDataset(val_x, val_y)
train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True) #only shuffle the training data
val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Cleanup the unneeded variables to save memory.<br>
#
# **notes: if you need to use these variables later, then you may remove this block or clean up unneeded variables later<br>the data size is quite huge, so be aware of memory usage in colab**

# %%
#import gc

del train, train_label, train_x, train_y, val_x, val_y
gc.collect()
# Out:
# 150

# %% [markdown]
# ## Create Model

# %% [markdown]
# Define model architecture, you are encouraged to change and experiment with the model architecture.
# * https://ensemble-pytorch.readthedocs.io/en/latest/

# %%
import torch
import torch.nn as nn
class Classifier(nn.Module):
    def __init__(self):
        super(Classifier, self).__init__()
        self.hl = 500
        self.lstm = nn.LSTM(39, self.hl, 2, bidirectional=True)
        self.fc = nn.Linear(self.hl*11*2, 39)
    
    def forward(self, x):
        out = x.view(x.size(0), 11, 39) #128*11*39
        out = out.permute(1, 0, 2) #11*128*39
        h0 = Variable(torch.zeros(2*2, x.size(0), self.hl).cuda())
        c0 = Variable(torch.zeros(2*2, x.size(0), self.hl).cuda())
        out, (hn, cn) = self.lstm(out, (h0, c0)) # 11*128*512
        out = out.permute(1, 0, 2) 
        out = out.reshape(x.size(0), self.hl*11*2) #128*(5632*2)
        out = self.fc(out) 
        return out

# %% [markdown]
# ## Training

# %%
#check device
def get_device():
    return 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# Fix random seeds for reproducibility.

# %%
# fix random seed
def same_seeds(seed):
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)  
    np.random.seed(seed)  
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

# %% [markdown]
# Feel free to change the training parameters here.

# %%
# !pip install torchensemble
from torchensemble import VotingClassifier
from torch.autograd import Variable
from torchensemble.utils.logging import set_logger
# Out:
# Requirement already satisfied: torchensemble in /usr/local/lib/python3.7/dist-packages (0.1.2)
# Requirement already satisfied: torchvision>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from torchensemble) (0.9.1+cu101)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from torchensemble) (1.8.1+cu101)
# Requirement already satisfied: scikit-learn>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from torchensemble) (0.24.1)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.2.2->torchensemble) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.2.2->torchensemble) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4.0->torchensemble) (3.7.4.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.23.0->torchensemble) (1.0.1)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.23.0->torchensemble) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.23.0->torchensemble) (2.1.0)

# %%
# fix random seed for reproducibility
same_seeds(0)

# get device 
device = get_device()
print(f'DEVICE: {device}')

# the path where checkpoint saved
model_path = './model.ckpt'

# create model, define a loss function, and optimizer
logger = set_logger("hw2_log")
model = VotingClassifier(estimator=Classifier ,n_estimators=12, cuda=True).to(device)
optimizer = model.set_optimizer("Adam", lr=0.001, weight_decay=1e-6)
model.fit(train_loader, epochs=2, test_loader=val_loader)
# Out:
# DEVICE: cuda
# Log will be saved in '/content/logs'.
# Start logging into file /content/logs/hw2_log-2021_04_01_17_14.log...
# Estimator: 000 | Epoch: 000 | Batch: 000 | Loss: 3.66658 | Correct: 0/128
# Estimator: 000 | Epoch: 000 | Batch: 100 | Loss: 1.65488 | Correct: 60/128
# Estimator: 000 | Epoch: 000 | Batch: 200 | Loss: 1.40717 | Correct: 74/128
# Estimator: 000 | Epoch: 000 | Batch: 300 | Loss: 1.18468 | Correct: 90/128
# Estimator: 000 | Epoch: 000 | Batch: 400 | Loss: 1.24836 | Correct: 78/128
# Estimator: 000 | Epoch: 000 | Batch: 500 | Loss: 1.03148 | Correct: 84/128
# Estimator: 000 | Epoch: 000 | Batch: 600 | Loss: 1.33526 | Correct: 72/128
# Estimator: 000 | Epoch: 000 | Batch: 700 | Loss: 1.18259 | Correct: 79/128
# Estimator: 000 | Epoch: 000 | Batch: 800 | Loss: 1.20046 | Correct: 82/128
# Estimator: 000 | Epoch: 000 | Batch: 900 | Loss: 1.00830 | Correct: 90/128
# Estimator: 000 | Epoch: 000 | Batch: 1000 | Loss: 0.98859 | Correct: 84/128
# Estimator: 000 | Epoch: 000 | Batch: 1100 | Loss: 0.90460 | Correct: 89/128
# Estimator: 000 | Epoch: 000 | Batch: 1200 | Loss: 0.88943 | Correct: 86/128
# Estimator: 000 | Epoch: 000 | Batch: 1300 | Loss: 0.92509 | Correct: 85/128
# Estimator: 000 | Epoch: 000 | Batch: 1400 | Loss: 1.01094 | Correct: 86/128
# Estimator: 000 | Epoch: 000 | Batch: 1500 | Loss: 0.97086 | Correct: 90/128
# Estimator: 000 | Epoch: 000 | Batch: 1600 | Loss: 0.91884 | Correct: 89/128
# Estimator: 000 | Epoch: 000 | Batch: 1700 | Loss: 0.82883 | Correct: 93/128
# Estimator: 000 | Epoch: 000 | Batch: 1800 | Loss: 0.84903 | Correct: 87/128
# Estimator: 000 | Epoch: 000 | Batch: 1900 | Loss: 0.90959 | Correct: 90/128
# Estimator: 000 | Epoch: 000 | Batch: 2000 | Loss: 0.75644 | Correct: 98/128
# Estimator: 000 | Epoch: 000 | Batch: 2100 | Loss: 1.01807 | Correct: 87/128
# Estimator: 000 | Epoch: 000 | Batch: 2200 | Loss: 0.89639 | Correct: 89/128
# Estimator: 000 | Epoch: 000 | Batch: 2300 | Loss: 0.86664 | Correct: 88/128
# Estimator: 000 | Epoch: 000 | Batch: 2400 | Loss: 0.91080 | Correct: 84/128
# Estimator: 000 | Epoch: 000 | Batch: 2500 | Loss: 0.69653 | Correct: 95/128
# Estimator: 000 | Epoch: 000 | Batch: 2600 | Loss: 0.69385 | Correct: 98/128
# Estimator: 000 | Epoch: 000 | Batch: 2700 | Loss: 0.71394 | Correct: 99/128
# Estimator: 000 | Epoch: 000 | Batch: 2800 | Loss: 0.82616 | Correct: 97/128
# Estimator: 000 | Epoch: 000 | Batch: 2900 | Loss: 0.72240 | Correct: 96/128
# Estimator: 000 | Epoch: 000 | Batch: 3000 | Loss: 0.95781 | Correct: 87/128
# Estimator: 000 | Epoch: 000 | Batch: 3100 | Loss: 0.78528 | Correct: 92/128
# Estimator: 000 | Epoch: 000 | Batch: 3200 | Loss: 0.84490 | Correct: 88/128
# Estimator: 000 | Epoch: 000 | Batch: 3300 | Loss: 0.65961 | Correct: 98/128
# Estimator: 000 | Epoch: 000 | Batch: 3400 | Loss: 0.63458 | Correct: 100/128
# Estimator: 000 | Epoch: 000 | Batch: 3500 | Loss: 0.70157 | Correct: 94/128
# Estimator: 000 | Epoch: 000 | Batch: 3600 | Loss: 0.66585 | Correct: 98/128
# Estimator: 000 | Epoch: 000 | Batch: 3700 | Loss: 0.69846 | Correct: 97/128
# Estimator: 000 | Epoch: 000 | Batch: 3800 | Loss: 0.75108 | Correct: 94/128
# Estimator: 000 | Epoch: 000 | Batch: 3900 | Loss: 0.75788 | Correct: 96/128
# Estimator: 000 | Epoch: 000 | Batch: 4000 | Loss: 0.62162 | Correct: 102/128
# Estimator: 000 | Epoch: 000 | Batch: 4100 | Loss: 0.56879 | Correct: 104/128
# Estimator: 000 | Epoch: 000 | Batch: 4200 | Loss: 0.79340 | Correct: 89/128
# Estimator: 000 | Epoch: 000 | Batch: 4300 | Loss: 0.57838 | Correct: 103/128
# Estimator: 000 | Epoch: 000 | Batch: 4400 | Loss: 0.74894 | Correct: 101/128
# Estimator: 000 | Epoch: 000 | Batch: 4500 | Loss: 0.75796 | Correct: 98/128
# Estimator: 000 | Epoch: 000 | Batch: 4600 | Loss: 0.71089 | Correct: 96/128
# Estimator: 000 | Epoch: 000 | Batch: 4700 | Loss: 0.52585 | Correct: 100/128
# Estimator: 000 | Epoch: 000 | Batch: 4800 | Loss: 0.70871 | Correct: 99/128
# Estimator: 000 | Epoch: 000 | Batch: 4900 | Loss: 0.67472 | Correct: 96/128
# Estimator: 000 | Epoch: 000 | Batch: 5000 | Loss: 0.79106 | Correct: 94/128
# Estimator: 000 | Epoch: 000 | Batch: 5100 | Loss: 0.65071 | Correct: 98/128
# Estimator: 000 | Epoch: 000 | Batch: 5200 | Loss: 0.67011 | Correct: 104/128
# Estimator: 000 | Epoch: 000 | Batch: 5300 | Loss: 0.55719 | Correct: 101/128
# Estimator: 000 | Epoch: 000 | Batch: 5400 | Loss: 0.48423 | Correct: 107/128
# Estimator: 000 | Epoch: 000 | Batch: 5500 | Loss: 0.56822 | Correct: 106/128
# Estimator: 000 | Epoch: 000 | Batch: 5600 | Loss: 0.68744 | Correct: 97/128
# Estimator: 000 | Epoch: 000 | Batch: 5700 | Loss: 0.51155 | Correct: 107/128
# Estimator: 000 | Epoch: 000 | Batch: 5800 | Loss: 0.67224 | Correct: 100/128
# Estimator: 000 | Epoch: 000 | Batch: 5900 | Loss: 0.63146 | Correct: 100/128
# Estimator: 000 | Epoch: 000 | Batch: 6000 | Loss: 0.50559 | Correct: 105/128
# Estimator: 000 | Epoch: 000 | Batch: 6100 | Loss: 0.70058 | Correct: 99/128
# Estimator: 000 | Epoch: 000 | Batch: 6200 | Loss: 0.68952 | Correct: 101/128
# Estimator: 000 | Epoch: 000 | Batch: 6300 | Loss: 0.57584 | Correct: 101/128
# Estimator: 000 | Epoch: 000 | Batch: 6400 | Loss: 0.46356 | Correct: 110/128
# Estimator: 000 | Epoch: 000 | Batch: 6500 | Loss: 0.69270 | Correct: 98/128
# Estimator: 000 | Epoch: 000 | Batch: 6600 | Loss: 0.60862 | Correct: 97/128
# Estimator: 000 | Epoch: 000 | Batch: 6700 | Loss: 0.53529 | Correct: 107/128
# Estimator: 000 | Epoch: 000 | Batch: 6800 | Loss: 0.59061 | Correct: 100/128
# Estimator: 000 | Epoch: 000 | Batch: 6900 | Loss: 0.58340 | Correct: 105/128
# Estimator: 000 | Epoch: 000 | Batch: 7000 | Loss: 0.55831 | Correct: 103/128
# Estimator: 000 | Epoch: 000 | Batch: 7100 | Loss: 0.43542 | Correct: 108/128
# Estimator: 000 | Epoch: 000 | Batch: 7200 | Loss: 0.60912 | Correct: 106/128
# Estimator: 000 | Epoch: 000 | Batch: 7300 | Loss: 0.50113 | Correct: 107/128
# Estimator: 000 | Epoch: 000 | Batch: 7400 | Loss: 0.56866 | Correct: 102/128
# Estimator: 000 | Epoch: 000 | Batch: 7500 | Loss: 0.65801 | Correct: 105/128
# Estimator: 000 | Epoch: 000 | Batch: 7600 | Loss: 0.53694 | Correct: 102/128
# Estimator: 000 | Epoch: 000 | Batch: 7700 | Loss: 0.52274 | Correct: 107/128
# Estimator: 000 | Epoch: 000 | Batch: 7800 | Loss: 0.59795 | Correct: 103/128
# Estimator: 000 | Epoch: 000 | Batch: 7900 | Loss: 0.69045 | Correct: 100/128
# Estimator: 000 | Epoch: 000 | Batch: 8000 | Loss: 0.67639 | Correct: 94/128
# Estimator: 000 | Epoch: 000 | Batch: 8100 | Loss: 0.61701 | Correct: 105/128
# Estimator: 000 | Epoch: 000 | Batch: 8200 | Loss: 0.55323 | Correct: 107/128
# Estimator: 000 | Epoch: 000 | Batch: 8300 | Loss: 0.71713 | Correct: 98/128
# Estimator: 000 | Epoch: 000 | Batch: 8400 | Loss: 0.61095 | Correct: 104/128
# Estimator: 000 | Epoch: 000 | Batch: 8500 | Loss: 0.37470 | Correct: 114/128
# Estimator: 000 | Epoch: 000 | Batch: 8600 | Loss: 0.45957 | Correct: 105/128
# Estimator: 001 | Epoch: 000 | Batch: 000 | Loss: 3.66883 | Correct: 0/128
# Estimator: 001 | Epoch: 000 | Batch: 100 | Loss: 1.62071 | Correct: 69/128
# Estimator: 001 | Epoch: 000 | Batch: 200 | Loss: 1.46913 | Correct: 74/128
# Estimator: 001 | Epoch: 000 | Batch: 300 | Loss: 1.01092 | Correct: 91/128
# Estimator: 001 | Epoch: 000 | Batch: 400 | Loss: 1.24111 | Correct: 83/128
# Estimator: 001 | Epoch: 000 | Batch: 500 | Loss: 1.07717 | Correct: 85/128
# Estimator: 001 | Epoch: 000 | Batch: 600 | Loss: 1.29449 | Correct: 74/128
# Estimator: 001 | Epoch: 000 | Batch: 700 | Loss: 1.14975 | Correct: 82/128
# Estimator: 001 | Epoch: 000 | Batch: 800 | Loss: 1.06446 | Correct: 82/128
# Estimator: 001 | Epoch: 000 | Batch: 900 | Loss: 0.90464 | Correct: 93/128
# Estimator: 001 | Epoch: 000 | Batch: 1000 | Loss: 1.11735 | Correct: 77/128
# Estimator: 001 | Epoch: 000 | Batch: 1100 | Loss: 0.94255 | Correct: 92/128
# Estimator: 001 | Epoch: 000 | Batch: 1200 | Loss: 1.03173 | Correct: 84/128
# Estimator: 001 | Epoch: 000 | Batch: 1300 | Loss: 1.08351 | Correct: 82/128
# Estimator: 001 | Epoch: 000 | Batch: 1400 | Loss: 0.91603 | Correct: 85/128
# Estimator: 001 | Epoch: 000 | Batch: 1500 | Loss: 1.08215 | Correct: 80/128
# Estimator: 001 | Epoch: 000 | Batch: 1600 | Loss: 1.07576 | Correct: 88/128
# Estimator: 001 | Epoch: 000 | Batch: 1700 | Loss: 0.86783 | Correct: 90/128
# Estimator: 001 | Epoch: 000 | Batch: 1800 | Loss: 0.86755 | Correct: 96/128
# Estimator: 001 | Epoch: 000 | Batch: 1900 | Loss: 0.79047 | Correct: 91/128
# Estimator: 001 | Epoch: 000 | Batch: 2000 | Loss: 0.77304 | Correct: 96/128
# Estimator: 001 | Epoch: 000 | Batch: 2100 | Loss: 1.01340 | Correct: 86/128
# Estimator: 001 | Epoch: 000 | Batch: 2200 | Loss: 0.99034 | Correct: 88/128
# Estimator: 001 | Epoch: 000 | Batch: 2300 | Loss: 0.79473 | Correct: 90/128
# Estimator: 001 | Epoch: 000 | Batch: 2400 | Loss: 0.82310 | Correct: 91/128
# Estimator: 001 | Epoch: 000 | Batch: 2500 | Loss: 0.79875 | Correct: 89/128
# Estimator: 001 | Epoch: 000 | Batch: 2600 | Loss: 0.74468 | Correct: 99/128
# Estimator: 001 | Epoch: 000 | Batch: 2700 | Loss: 0.72023 | Correct: 94/128
# Estimator: 001 | Epoch: 000 | Batch: 2800 | Loss: 0.94947 | Correct: 91/128
# Estimator: 001 | Epoch: 000 | Batch: 2900 | Loss: 0.89670 | Correct: 89/128
# Estimator: 001 | Epoch: 000 | Batch: 3000 | Loss: 0.79105 | Correct: 96/128
# Estimator: 001 | Epoch: 000 | Batch: 3100 | Loss: 0.76480 | Correct: 95/128
# Estimator: 001 | Epoch: 000 | Batch: 3200 | Loss: 0.66022 | Correct: 101/128
# Estimator: 001 | Epoch: 000 | Batch: 3300 | Loss: 0.85076 | Correct: 89/128
# Estimator: 001 | Epoch: 000 | Batch: 3400 | Loss: 0.86403 | Correct: 93/128
# Estimator: 001 | Epoch: 000 | Batch: 3500 | Loss: 1.07945 | Correct: 82/128
# Estimator: 001 | Epoch: 000 | Batch: 3600 | Loss: 0.68200 | Correct: 98/128
# Estimator: 001 | Epoch: 000 | Batch: 3700 | Loss: 0.67803 | Correct: 98/128
# Estimator: 001 | Epoch: 000 | Batch: 3800 | Loss: 0.87170 | Correct: 88/128
# Estimator: 001 | Epoch: 000 | Batch: 3900 | Loss: 0.90938 | Correct: 90/128
# Estimator: 001 | Epoch: 000 | Batch: 4000 | Loss: 0.73966 | Correct: 97/128
# Estimator: 001 | Epoch: 000 | Batch: 4100 | Loss: 0.72364 | Correct: 100/128
# Estimator: 001 | Epoch: 000 | Batch: 4200 | Loss: 0.90159 | Correct: 87/128
# Estimator: 001 | Epoch: 000 | Batch: 4300 | Loss: 0.76077 | Correct: 96/128
# Estimator: 001 | Epoch: 000 | Batch: 4400 | Loss: 0.72346 | Correct: 90/128
# Estimator: 001 | Epoch: 000 | Batch: 4500 | Loss: 0.70608 | Correct: 94/128
# Estimator: 001 | Epoch: 000 | Batch: 4600 | Loss: 0.75398 | Correct: 97/128
# Estimator: 001 | Epoch: 000 | Batch: 4700 | Loss: 0.76314 | Correct: 99/128
# Estimator: 001 | Epoch: 000 | Batch: 4800 | Loss: 0.68713 | Correct: 100/128
# Estimator: 001 | Epoch: 000 | Batch: 4900 | Loss: 0.78333 | Correct: 97/128
# Estimator: 001 | Epoch: 000 | Batch: 5000 | Loss: 0.44882 | Correct: 104/128
# Estimator: 001 | Epoch: 000 | Batch: 5100 | Loss: 0.91797 | Correct: 92/128
# Estimator: 001 | Epoch: 000 | Batch: 5200 | Loss: 0.63900 | Correct: 96/128
# Estimator: 001 | Epoch: 000 | Batch: 5300 | Loss: 0.70389 | Correct: 96/128
# Estimator: 001 | Epoch: 000 | Batch: 5400 | Loss: 0.62376 | Correct: 101/128
# Estimator: 001 | Epoch: 000 | Batch: 5500 | Loss: 0.65837 | Correct: 104/128
# Estimator: 001 | Epoch: 000 | Batch: 5600 | Loss: 0.69158 | Correct: 96/128
# Estimator: 001 | Epoch: 000 | Batch: 5700 | Loss: 0.76349 | Correct: 92/128
# Estimator: 001 | Epoch: 000 | Batch: 5800 | Loss: 0.58932 | Correct: 100/128
# Estimator: 001 | Epoch: 000 | Batch: 5900 | Loss: 0.68837 | Correct: 99/128
# Estimator: 001 | Epoch: 000 | Batch: 6000 | Loss: 0.61391 | Correct: 103/128
# Estimator: 001 | Epoch: 000 | Batch: 6100 | Loss: 0.63412 | Correct: 106/128
# Estimator: 001 | Epoch: 000 | Batch: 6200 | Loss: 0.52127 | Correct: 102/128
# Estimator: 001 | Epoch: 000 | Batch: 6300 | Loss: 0.63010 | Correct: 97/128
# Estimator: 001 | Epoch: 000 | Batch: 6400 | Loss: 0.64068 | Correct: 101/128
# Estimator: 001 | Epoch: 000 | Batch: 6500 | Loss: 0.56219 | Correct: 104/128
# Estimator: 001 | Epoch: 000 | Batch: 6600 | Loss: 0.63549 | Correct: 99/128
# Estimator: 001 | Epoch: 000 | Batch: 6700 | Loss: 0.52003 | Correct: 105/128
# Estimator: 001 | Epoch: 000 | Batch: 6800 | Loss: 0.67537 | Correct: 95/128
# Estimator: 001 | Epoch: 000 | Batch: 6900 | Loss: 0.62539 | Correct: 103/128
# Estimator: 001 | Epoch: 000 | Batch: 7000 | Loss: 0.58283 | Correct: 106/128
# Estimator: 001 | Epoch: 000 | Batch: 7100 | Loss: 0.52971 | Correct: 107/128
# Estimator: 001 | Epoch: 000 | Batch: 7200 | Loss: 0.50501 | Correct: 103/128
# Estimator: 001 | Epoch: 000 | Batch: 7300 | Loss: 0.59645 | Correct: 101/128
# Estimator: 001 | Epoch: 000 | Batch: 7400 | Loss: 0.55439 | Correct: 104/128
# Estimator: 001 | Epoch: 000 | Batch: 7500 | Loss: 0.68154 | Correct: 100/128
# Estimator: 001 | Epoch: 000 | Batch: 7600 | Loss: 0.67451 | Correct: 98/128
# Estimator: 001 | Epoch: 000 | Batch: 7700 | Loss: 0.46566 | Correct: 108/128
# Estimator: 001 | Epoch: 000 | Batch: 7800 | Loss: 0.61874 | Correct: 102/128
# Estimator: 001 | Epoch: 000 | Batch: 7900 | Loss: 0.53765 | Correct: 102/128
# Estimator: 001 | Epoch: 000 | Batch: 8000 | Loss: 0.49986 | Correct: 108/128
# Estimator: 001 | Epoch: 000 | Batch: 8100 | Loss: 0.58034 | Correct: 100/128
# Estimator: 001 | Epoch: 000 | Batch: 8200 | Loss: 0.65824 | Correct: 102/128
# Estimator: 001 | Epoch: 000 | Batch: 8300 | Loss: 0.57089 | Correct: 101/128
# Estimator: 001 | Epoch: 000 | Batch: 8400 | Loss: 0.57407 | Correct: 105/128
# Estimator: 001 | Epoch: 000 | Batch: 8500 | Loss: 0.54516 | Correct: 107/128
# Estimator: 001 | Epoch: 000 | Batch: 8600 | Loss: 0.52596 | Correct: 102/128
# Estimator: 002 | Epoch: 000 | Batch: 000 | Loss: 3.66561 | Correct: 1/128
# Estimator: 002 | Epoch: 000 | Batch: 100 | Loss: 1.48706 | Correct: 77/128
# Estimator: 002 | Epoch: 000 | Batch: 200 | Loss: 1.50387 | Correct: 65/128
# Estimator: 002 | Epoch: 000 | Batch: 300 | Loss: 1.18183 | Correct: 82/128
# Estimator: 002 | Epoch: 000 | Batch: 400 | Loss: 1.02214 | Correct: 84/128
# Estimator: 002 | Epoch: 000 | Batch: 500 | Loss: 1.19471 | Correct: 77/128
# Estimator: 002 | Epoch: 000 | Batch: 600 | Loss: 1.17068 | Correct: 83/128
# Estimator: 002 | Epoch: 000 | Batch: 700 | Loss: 1.02934 | Correct: 84/128
# Estimator: 002 | Epoch: 000 | Batch: 800 | Loss: 0.92908 | Correct: 91/128
# Estimator: 002 | Epoch: 000 | Batch: 900 | Loss: 0.75708 | Correct: 97/128
# Estimator: 002 | Epoch: 000 | Batch: 1000 | Loss: 1.00113 | Correct: 85/128
# Estimator: 002 | Epoch: 000 | Batch: 1100 | Loss: 1.01300 | Correct: 84/128
# Estimator: 002 | Epoch: 000 | Batch: 1200 | Loss: 1.22822 | Correct: 79/128
# Estimator: 002 | Epoch: 000 | Batch: 1300 | Loss: 0.90527 | Correct: 88/128
# Estimator: 002 | Epoch: 000 | Batch: 1400 | Loss: 1.12338 | Correct: 86/128
# Estimator: 002 | Epoch: 000 | Batch: 1500 | Loss: 0.80861 | Correct: 92/128
# Estimator: 002 | Epoch: 000 | Batch: 1600 | Loss: 0.79032 | Correct: 99/128
# Estimator: 002 | Epoch: 000 | Batch: 1700 | Loss: 1.05859 | Correct: 81/128
# Estimator: 002 | Epoch: 000 | Batch: 1800 | Loss: 0.82866 | Correct: 94/128
# Estimator: 002 | Epoch: 000 | Batch: 1900 | Loss: 0.82100 | Correct: 93/128
# Estimator: 002 | Epoch: 000 | Batch: 2000 | Loss: 0.90591 | Correct: 85/128
# Estimator: 002 | Epoch: 000 | Batch: 2100 | Loss: 0.93501 | Correct: 89/128
# Estimator: 002 | Epoch: 000 | Batch: 2200 | Loss: 0.83755 | Correct: 92/128
# Estimator: 002 | Epoch: 000 | Batch: 2300 | Loss: 0.99116 | Correct: 87/128
# Estimator: 002 | Epoch: 000 | Batch: 2400 | Loss: 0.79963 | Correct: 99/128
# Estimator: 002 | Epoch: 000 | Batch: 2500 | Loss: 0.60249 | Correct: 96/128
# Estimator: 002 | Epoch: 000 | Batch: 2600 | Loss: 1.07698 | Correct: 86/128
# Estimator: 002 | Epoch: 000 | Batch: 2700 | Loss: 0.65578 | Correct: 100/128
# Estimator: 002 | Epoch: 000 | Batch: 2800 | Loss: 0.82840 | Correct: 94/128
# Estimator: 002 | Epoch: 000 | Batch: 2900 | Loss: 0.85141 | Correct: 93/128
# Estimator: 002 | Epoch: 000 | Batch: 3000 | Loss: 0.97127 | Correct: 85/128
# Estimator: 002 | Epoch: 000 | Batch: 3100 | Loss: 0.67048 | Correct: 100/128
# Estimator: 002 | Epoch: 000 | Batch: 3200 | Loss: 0.57100 | Correct: 106/128
# Estimator: 002 | Epoch: 000 | Batch: 3300 | Loss: 0.59054 | Correct: 106/128
# Estimator: 002 | Epoch: 000 | Batch: 3400 | Loss: 0.83386 | Correct: 95/128
# Estimator: 002 | Epoch: 000 | Batch: 3500 | Loss: 0.75132 | Correct: 92/128
# Estimator: 002 | Epoch: 000 | Batch: 3600 | Loss: 0.91253 | Correct: 88/128
# Estimator: 002 | Epoch: 000 | Batch: 3700 | Loss: 0.86302 | Correct: 94/128
# Estimator: 002 | Epoch: 000 | Batch: 3800 | Loss: 0.92278 | Correct: 95/128
# Estimator: 002 | Epoch: 000 | Batch: 3900 | Loss: 0.78170 | Correct: 95/128
# Estimator: 002 | Epoch: 000 | Batch: 4000 | Loss: 0.90912 | Correct: 92/128
# Estimator: 002 | Epoch: 000 | Batch: 4100 | Loss: 0.78475 | Correct: 95/128
# Estimator: 002 | Epoch: 000 | Batch: 4200 | Loss: 0.62277 | Correct: 101/128
# Estimator: 002 | Epoch: 000 | Batch: 4300 | Loss: 0.82650 | Correct: 90/128
# Estimator: 002 | Epoch: 000 | Batch: 4400 | Loss: 0.72289 | Correct: 93/128
# Estimator: 002 | Epoch: 000 | Batch: 4500 | Loss: 0.62695 | Correct: 103/128
# Estimator: 002 | Epoch: 000 | Batch: 4600 | Loss: 0.76897 | Correct: 95/128
# Estimator: 002 | Epoch: 000 | Batch: 4700 | Loss: 0.59937 | Correct: 103/128
# Estimator: 002 | Epoch: 000 | Batch: 4800 | Loss: 0.70937 | Correct: 99/128
# Estimator: 002 | Epoch: 000 | Batch: 4900 | Loss: 0.56758 | Correct: 108/128
# Estimator: 002 | Epoch: 000 | Batch: 5000 | Loss: 0.56206 | Correct: 102/128
# Estimator: 002 | Epoch: 000 | Batch: 5100 | Loss: 0.57372 | Correct: 108/128
# Estimator: 002 | Epoch: 000 | Batch: 5200 | Loss: 0.71585 | Correct: 101/128
# Estimator: 002 | Epoch: 000 | Batch: 5300 | Loss: 0.69216 | Correct: 96/128
# Estimator: 002 | Epoch: 000 | Batch: 5400 | Loss: 0.65492 | Correct: 96/128
# Estimator: 002 | Epoch: 000 | Batch: 5500 | Loss: 0.69324 | Correct: 95/128
# Estimator: 002 | Epoch: 000 | Batch: 5600 | Loss: 0.51128 | Correct: 103/128
# Estimator: 002 | Epoch: 000 | Batch: 5700 | Loss: 0.54358 | Correct: 103/128
# Estimator: 002 | Epoch: 000 | Batch: 5800 | Loss: 0.48766 | Correct: 106/128
# Estimator: 002 | Epoch: 000 | Batch: 5900 | Loss: 0.60511 | Correct: 106/128
# Estimator: 002 | Epoch: 000 | Batch: 6000 | Loss: 0.67692 | Correct: 102/128
# Estimator: 002 | Epoch: 000 | Batch: 6100 | Loss: 0.59073 | Correct: 105/128
# Estimator: 002 | Epoch: 000 | Batch: 6200 | Loss: 0.54744 | Correct: 100/128
# Estimator: 002 | Epoch: 000 | Batch: 6300 | Loss: 0.62358 | Correct: 102/128
# Estimator: 002 | Epoch: 000 | Batch: 6400 | Loss: 0.61410 | Correct: 101/128
# Estimator: 002 | Epoch: 000 | Batch: 6500 | Loss: 0.60225 | Correct: 105/128
# Estimator: 002 | Epoch: 000 | Batch: 6600 | Loss: 0.58570 | Correct: 101/128
# Estimator: 002 | Epoch: 000 | Batch: 6700 | Loss: 0.57833 | Correct: 102/128
# Estimator: 002 | Epoch: 000 | Batch: 6800 | Loss: 0.67674 | Correct: 98/128
# Estimator: 002 | Epoch: 000 | Batch: 6900 | Loss: 0.61663 | Correct: 103/128
# Estimator: 002 | Epoch: 000 | Batch: 7000 | Loss: 0.61557 | Correct: 96/128
# Estimator: 002 | Epoch: 000 | Batch: 7100 | Loss: 0.50657 | Correct: 104/128
# Estimator: 002 | Epoch: 000 | Batch: 7200 | Loss: 0.53390 | Correct: 105/128
# Estimator: 002 | Epoch: 000 | Batch: 7300 | Loss: 0.65589 | Correct: 104/128
# Estimator: 002 | Epoch: 000 | Batch: 7400 | Loss: 0.61484 | Correct: 100/128
# Estimator: 002 | Epoch: 000 | Batch: 7500 | Loss: 0.62014 | Correct: 103/128
# Estimator: 002 | Epoch: 000 | Batch: 7600 | Loss: 0.59797 | Correct: 105/128
# Estimator: 002 | Epoch: 000 | Batch: 7700 | Loss: 0.51568 | Correct: 101/128
# Estimator: 002 | Epoch: 000 | Batch: 7800 | Loss: 0.60598 | Correct: 103/128
# Estimator: 002 | Epoch: 000 | Batch: 7900 | Loss: 0.48238 | Correct: 105/128
# Estimator: 002 | Epoch: 000 | Batch: 8000 | Loss: 0.65597 | Correct: 100/128
# Estimator: 002 | Epoch: 000 | Batch: 8100 | Loss: 0.52130 | Correct: 106/128
# Estimator: 002 | Epoch: 000 | Batch: 8200 | Loss: 0.55702 | Correct: 109/128
# Estimator: 002 | Epoch: 000 | Batch: 8300 | Loss: 0.68335 | Correct: 99/128
# Estimator: 002 | Epoch: 000 | Batch: 8400 | Loss: 0.57440 | Correct: 98/128
# Estimator: 002 | Epoch: 000 | Batch: 8500 | Loss: 0.60941 | Correct: 104/128
# Estimator: 002 | Epoch: 000 | Batch: 8600 | Loss: 0.53396 | Correct: 106/128
# Estimator: 003 | Epoch: 000 | Batch: 000 | Loss: 3.66583 | Correct: 4/128
# Estimator: 003 | Epoch: 000 | Batch: 100 | Loss: 1.53736 | Correct: 66/128
# Estimator: 003 | Epoch: 000 | Batch: 200 | Loss: 1.39841 | Correct: 70/128
# Estimator: 003 | Epoch: 000 | Batch: 300 | Loss: 1.32593 | Correct: 76/128
# Estimator: 003 | Epoch: 000 | Batch: 400 | Loss: 1.33962 | Correct: 72/128
# Estimator: 003 | Epoch: 000 | Batch: 500 | Loss: 1.17561 | Correct: 79/128
# Estimator: 003 | Epoch: 000 | Batch: 600 | Loss: 0.96943 | Correct: 85/128
# Estimator: 003 | Epoch: 000 | Batch: 700 | Loss: 1.13048 | Correct: 74/128
# Estimator: 003 | Epoch: 000 | Batch: 800 | Loss: 1.09742 | Correct: 84/128
# Estimator: 003 | Epoch: 000 | Batch: 900 | Loss: 0.91500 | Correct: 90/128
# Estimator: 003 | Epoch: 000 | Batch: 1000 | Loss: 0.87313 | Correct: 91/128
# Estimator: 003 | Epoch: 000 | Batch: 1100 | Loss: 0.98560 | Correct: 87/128
# Estimator: 003 | Epoch: 000 | Batch: 1200 | Loss: 1.01440 | Correct: 80/128
# Estimator: 003 | Epoch: 000 | Batch: 1300 | Loss: 0.87730 | Correct: 92/128
# Estimator: 003 | Epoch: 000 | Batch: 1400 | Loss: 0.89812 | Correct: 93/128
# Estimator: 003 | Epoch: 000 | Batch: 1500 | Loss: 0.97684 | Correct: 83/128
# Estimator: 003 | Epoch: 000 | Batch: 1600 | Loss: 0.87451 | Correct: 93/128
# Estimator: 003 | Epoch: 000 | Batch: 1700 | Loss: 0.95782 | Correct: 94/128
# Estimator: 003 | Epoch: 000 | Batch: 1800 | Loss: 0.88535 | Correct: 94/128
# Estimator: 003 | Epoch: 000 | Batch: 1900 | Loss: 0.88569 | Correct: 92/128
# Estimator: 003 | Epoch: 000 | Batch: 2000 | Loss: 0.62379 | Correct: 104/128
# Estimator: 003 | Epoch: 000 | Batch: 2100 | Loss: 0.85623 | Correct: 93/128
# Estimator: 003 | Epoch: 000 | Batch: 2200 | Loss: 0.84618 | Correct: 93/128
# Estimator: 003 | Epoch: 000 | Batch: 2300 | Loss: 0.77832 | Correct: 97/128
# Estimator: 003 | Epoch: 000 | Batch: 2400 | Loss: 0.72280 | Correct: 98/128
# Estimator: 003 | Epoch: 000 | Batch: 2500 | Loss: 0.91363 | Correct: 87/128
# Estimator: 003 | Epoch: 000 | Batch: 2600 | Loss: 0.76629 | Correct: 92/128
# Estimator: 003 | Epoch: 000 | Batch: 2700 | Loss: 0.82075 | Correct: 94/128
# Estimator: 003 | Epoch: 000 | Batch: 2800 | Loss: 0.80184 | Correct: 94/128
# Estimator: 003 | Epoch: 000 | Batch: 2900 | Loss: 0.62481 | Correct: 103/128
# Estimator: 003 | Epoch: 000 | Batch: 3000 | Loss: 0.78005 | Correct: 93/128
# Estimator: 003 | Epoch: 000 | Batch: 3100 | Loss: 0.72234 | Correct: 99/128
# Estimator: 003 | Epoch: 000 | Batch: 3200 | Loss: 0.73445 | Correct: 94/128
# Estimator: 003 | Epoch: 000 | Batch: 3300 | Loss: 0.78557 | Correct: 100/128
# Estimator: 003 | Epoch: 000 | Batch: 3400 | Loss: 0.81612 | Correct: 96/128
# Estimator: 003 | Epoch: 000 | Batch: 3500 | Loss: 0.72584 | Correct: 100/128
# Estimator: 003 | Epoch: 000 | Batch: 3600 | Loss: 0.71476 | Correct: 99/128
# Estimator: 003 | Epoch: 000 | Batch: 3700 | Loss: 0.77110 | Correct: 92/128
# Estimator: 003 | Epoch: 000 | Batch: 3800 | Loss: 0.73815 | Correct: 98/128
# Estimator: 003 | Epoch: 000 | Batch: 3900 | Loss: 0.64919 | Correct: 101/128
# Estimator: 003 | Epoch: 000 | Batch: 4000 | Loss: 0.71803 | Correct: 96/128
# Estimator: 003 | Epoch: 000 | Batch: 4100 | Loss: 0.67407 | Correct: 100/128
# Estimator: 003 | Epoch: 000 | Batch: 4200 | Loss: 0.65132 | Correct: 98/128
# Estimator: 003 | Epoch: 000 | Batch: 4300 | Loss: 0.93961 | Correct: 96/128
# Estimator: 003 | Epoch: 000 | Batch: 4400 | Loss: 0.73554 | Correct: 93/128
# Estimator: 003 | Epoch: 000 | Batch: 4500 | Loss: 0.67418 | Correct: 99/128
# Estimator: 003 | Epoch: 000 | Batch: 4600 | Loss: 0.95406 | Correct: 90/128
# Estimator: 003 | Epoch: 000 | Batch: 4700 | Loss: 0.67144 | Correct: 97/128
# Estimator: 003 | Epoch: 000 | Batch: 4800 | Loss: 0.65488 | Correct: 102/128
# Estimator: 003 | Epoch: 000 | Batch: 4900 | Loss: 0.63979 | Correct: 103/128
# Estimator: 003 | Epoch: 000 | Batch: 5000 | Loss: 0.72442 | Correct: 94/128
# Estimator: 003 | Epoch: 000 | Batch: 5100 | Loss: 0.75119 | Correct: 96/128
# Estimator: 003 | Epoch: 000 | Batch: 5200 | Loss: 0.72491 | Correct: 95/128
# Estimator: 003 | Epoch: 000 | Batch: 5300 | Loss: 0.70210 | Correct: 95/128
# Estimator: 003 | Epoch: 000 | Batch: 5400 | Loss: 0.81577 | Correct: 99/128
# Estimator: 003 | Epoch: 000 | Batch: 5500 | Loss: 0.49043 | Correct: 102/128
# Estimator: 003 | Epoch: 000 | Batch: 5600 | Loss: 0.64715 | Correct: 96/128
# Estimator: 003 | Epoch: 000 | Batch: 5700 | Loss: 0.72257 | Correct: 95/128
# Estimator: 003 | Epoch: 000 | Batch: 5800 | Loss: 0.74635 | Correct: 97/128
# Estimator: 003 | Epoch: 000 | Batch: 5900 | Loss: 0.68406 | Correct: 97/128
# Estimator: 003 | Epoch: 000 | Batch: 6000 | Loss: 0.47214 | Correct: 110/128
# Estimator: 003 | Epoch: 000 | Batch: 6100 | Loss: 0.81993 | Correct: 98/128
# Estimator: 003 | Epoch: 000 | Batch: 6200 | Loss: 0.61857 | Correct: 101/128
# Estimator: 003 | Epoch: 000 | Batch: 6300 | Loss: 0.61445 | Correct: 101/128
# Estimator: 003 | Epoch: 000 | Batch: 6400 | Loss: 0.64056 | Correct: 100/128
# Estimator: 003 | Epoch: 000 | Batch: 6500 | Loss: 0.65969 | Correct: 97/128
# Estimator: 003 | Epoch: 000 | Batch: 6600 | Loss: 0.61344 | Correct: 100/128
# Estimator: 003 | Epoch: 000 | Batch: 6700 | Loss: 0.60114 | Correct: 103/128
# Estimator: 003 | Epoch: 000 | Batch: 6800 | Loss: 0.73109 | Correct: 99/128
# Estimator: 003 | Epoch: 000 | Batch: 6900 | Loss: 0.53601 | Correct: 104/128
# Estimator: 003 | Epoch: 000 | Batch: 7000 | Loss: 0.63235 | Correct: 99/128
# Estimator: 003 | Epoch: 000 | Batch: 7100 | Loss: 0.55859 | Correct: 105/128
# Estimator: 003 | Epoch: 000 | Batch: 7200 | Loss: 0.59690 | Correct: 98/128
# Estimator: 003 | Epoch: 000 | Batch: 7300 | Loss: 0.73513 | Correct: 96/128
# Estimator: 003 | Epoch: 000 | Batch: 7400 | Loss: 0.56024 | Correct: 103/128
# Estimator: 003 | Epoch: 000 | Batch: 7500 | Loss: 0.63947 | Correct: 102/128
# Estimator: 003 | Epoch: 000 | Batch: 7600 | Loss: 0.57460 | Correct: 102/128
# Estimator: 003 | Epoch: 000 | Batch: 7700 | Loss: 0.60271 | Correct: 99/128
# Estimator: 003 | Epoch: 000 | Batch: 7800 | Loss: 0.59694 | Correct: 101/128
# Estimator: 003 | Epoch: 000 | Batch: 7900 | Loss: 0.66985 | Correct: 100/128
# Estimator: 003 | Epoch: 000 | Batch: 8000 | Loss: 0.64246 | Correct: 95/128
# Estimator: 003 | Epoch: 000 | Batch: 8100 | Loss: 0.73009 | Correct: 91/128
# Estimator: 003 | Epoch: 000 | Batch: 8200 | Loss: 0.43407 | Correct: 107/128
# Estimator: 003 | Epoch: 000 | Batch: 8300 | Loss: 0.58335 | Correct: 101/128
# Estimator: 003 | Epoch: 000 | Batch: 8400 | Loss: 0.61285 | Correct: 101/128
# Estimator: 003 | Epoch: 000 | Batch: 8500 | Loss: 0.55627 | Correct: 108/128
# Estimator: 003 | Epoch: 000 | Batch: 8600 | Loss: 0.35814 | Correct: 111/128
# Estimator: 004 | Epoch: 000 | Batch: 000 | Loss: 3.66760 | Correct: 2/128
# Estimator: 004 | Epoch: 000 | Batch: 100 | Loss: 2.13781 | Correct: 50/128
# Estimator: 004 | Epoch: 000 | Batch: 200 | Loss: 1.38023 | Correct: 77/128
# Estimator: 004 | Epoch: 000 | Batch: 300 | Loss: 1.02921 | Correct: 83/128
# Estimator: 004 | Epoch: 000 | Batch: 400 | Loss: 1.26816 | Correct: 78/128
# Estimator: 004 | Epoch: 000 | Batch: 500 | Loss: 1.13919 | Correct: 81/128
# Estimator: 004 | Epoch: 000 | Batch: 600 | Loss: 1.08646 | Correct: 82/128
# Estimator: 004 | Epoch: 000 | Batch: 700 | Loss: 1.12815 | Correct: 76/128
# Estimator: 004 | Epoch: 000 | Batch: 800 | Loss: 1.19430 | Correct: 76/128
# Estimator: 004 | Epoch: 000 | Batch: 900 | Loss: 1.11778 | Correct: 78/128
# Estimator: 004 | Epoch: 000 | Batch: 1000 | Loss: 0.92119 | Correct: 85/128
# Estimator: 004 | Epoch: 000 | Batch: 1100 | Loss: 1.05233 | Correct: 86/128
# Estimator: 004 | Epoch: 000 | Batch: 1200 | Loss: 0.83454 | Correct: 95/128
# Estimator: 004 | Epoch: 000 | Batch: 1300 | Loss: 1.00907 | Correct: 88/128
# Estimator: 004 | Epoch: 000 | Batch: 1400 | Loss: 0.85205 | Correct: 97/128
# Estimator: 004 | Epoch: 000 | Batch: 1500 | Loss: 0.89120 | Correct: 91/128
# Estimator: 004 | Epoch: 000 | Batch: 1600 | Loss: 0.85854 | Correct: 88/128
# Estimator: 004 | Epoch: 000 | Batch: 1700 | Loss: 1.11306 | Correct: 83/128
# Estimator: 004 | Epoch: 000 | Batch: 1800 | Loss: 0.95737 | Correct: 90/128
# Estimator: 004 | Epoch: 000 | Batch: 1900 | Loss: 0.78176 | Correct: 96/128
# Estimator: 004 | Epoch: 000 | Batch: 2000 | Loss: 0.67727 | Correct: 98/128
# Estimator: 004 | Epoch: 000 | Batch: 2100 | Loss: 1.05993 | Correct: 88/128
# Estimator: 004 | Epoch: 000 | Batch: 2200 | Loss: 0.92792 | Correct: 87/128
# Estimator: 004 | Epoch: 000 | Batch: 2300 | Loss: 0.87272 | Correct: 91/128
# Estimator: 004 | Epoch: 000 | Batch: 2400 | Loss: 0.75914 | Correct: 95/128
# Estimator: 004 | Epoch: 000 | Batch: 2500 | Loss: 0.75039 | Correct: 104/128
# Estimator: 004 | Epoch: 000 | Batch: 2600 | Loss: 0.68029 | Correct: 98/128
# Estimator: 004 | Epoch: 000 | Batch: 2700 | Loss: 0.80025 | Correct: 95/128
# Estimator: 004 | Epoch: 000 | Batch: 2800 | Loss: 0.78032 | Correct: 91/128
# Estimator: 004 | Epoch: 000 | Batch: 2900 | Loss: 0.87450 | Correct: 94/128
# Estimator: 004 | Epoch: 000 | Batch: 3000 | Loss: 0.64870 | Correct: 101/128
# Estimator: 004 | Epoch: 000 | Batch: 3100 | Loss: 0.84626 | Correct: 96/128
# Estimator: 004 | Epoch: 000 | Batch: 3200 | Loss: 0.81242 | Correct: 90/128
# Estimator: 004 | Epoch: 000 | Batch: 3300 | Loss: 0.70408 | Correct: 98/128
# Estimator: 004 | Epoch: 000 | Batch: 3400 | Loss: 0.96718 | Correct: 88/128
# Estimator: 004 | Epoch: 000 | Batch: 3500 | Loss: 0.75861 | Correct: 97/128
# Estimator: 004 | Epoch: 000 | Batch: 3600 | Loss: 0.78057 | Correct: 100/128
# Estimator: 004 | Epoch: 000 | Batch: 3700 | Loss: 0.82780 | Correct: 91/128
# Estimator: 004 | Epoch: 000 | Batch: 3800 | Loss: 0.57936 | Correct: 104/128
# Estimator: 004 | Epoch: 000 | Batch: 3900 | Loss: 0.70613 | Correct: 96/128
# Estimator: 004 | Epoch: 000 | Batch: 4000 | Loss: 0.86260 | Correct: 95/128
# Estimator: 004 | Epoch: 000 | Batch: 4100 | Loss: 0.89907 | Correct: 86/128
# Estimator: 004 | Epoch: 000 | Batch: 4200 | Loss: 0.61692 | Correct: 99/128
# Estimator: 004 | Epoch: 000 | Batch: 4300 | Loss: 0.75932 | Correct: 94/128
# Estimator: 004 | Epoch: 000 | Batch: 4400 | Loss: 0.82433 | Correct: 92/128
# Estimator: 004 | Epoch: 000 | Batch: 4500 | Loss: 0.63410 | Correct: 105/128
# Estimator: 004 | Epoch: 000 | Batch: 4600 | Loss: 0.65949 | Correct: 101/128
# Estimator: 004 | Epoch: 000 | Batch: 4700 | Loss: 0.76301 | Correct: 91/128
# Estimator: 004 | Epoch: 000 | Batch: 4800 | Loss: 0.82095 | Correct: 93/128
# Estimator: 004 | Epoch: 000 | Batch: 4900 | Loss: 0.65043 | Correct: 97/128
# Estimator: 004 | Epoch: 000 | Batch: 5000 | Loss: 0.64432 | Correct: 100/128
# Estimator: 004 | Epoch: 000 | Batch: 5100 | Loss: 0.73695 | Correct: 95/128
# Estimator: 004 | Epoch: 000 | Batch: 5200 | Loss: 0.78411 | Correct: 90/128
# Estimator: 004 | Epoch: 000 | Batch: 5300 | Loss: 0.89133 | Correct: 91/128
# Estimator: 004 | Epoch: 000 | Batch: 5400 | Loss: 0.61630 | Correct: 99/128
# Estimator: 004 | Epoch: 000 | Batch: 5500 | Loss: 0.70730 | Correct: 96/128
# Estimator: 004 | Epoch: 000 | Batch: 5600 | Loss: 0.51973 | Correct: 106/128
# Estimator: 004 | Epoch: 000 | Batch: 5700 | Loss: 0.53642 | Correct: 106/128
# Estimator: 004 | Epoch: 000 | Batch: 5800 | Loss: 0.41289 | Correct: 111/128
# Estimator: 004 | Epoch: 000 | Batch: 5900 | Loss: 0.66563 | Correct: 105/128
# Estimator: 004 | Epoch: 000 | Batch: 6000 | Loss: 0.77290 | Correct: 98/128
# Estimator: 004 | Epoch: 000 | Batch: 6100 | Loss: 0.57648 | Correct: 103/128
# Estimator: 004 | Epoch: 000 | Batch: 6200 | Loss: 0.67138 | Correct: 97/128
# Estimator: 004 | Epoch: 000 | Batch: 6300 | Loss: 0.54249 | Correct: 104/128
# Estimator: 004 | Epoch: 000 | Batch: 6400 | Loss: 0.68026 | Correct: 98/128
# Estimator: 004 | Epoch: 000 | Batch: 6500 | Loss: 0.57391 | Correct: 103/128
# Estimator: 004 | Epoch: 000 | Batch: 6600 | Loss: 0.65026 | Correct: 96/128
# Estimator: 004 | Epoch: 000 | Batch: 6700 | Loss: 0.44640 | Correct: 109/128
# Estimator: 004 | Epoch: 000 | Batch: 6800 | Loss: 0.60950 | Correct: 103/128
# Estimator: 004 | Epoch: 000 | Batch: 6900 | Loss: 0.52291 | Correct: 106/128
# Estimator: 004 | Epoch: 000 | Batch: 7000 | Loss: 0.68172 | Correct: 104/128
# Estimator: 004 | Epoch: 000 | Batch: 7100 | Loss: 0.52962 | Correct: 104/128
# Estimator: 004 | Epoch: 000 | Batch: 7200 | Loss: 0.52148 | Correct: 106/128
# Estimator: 004 | Epoch: 000 | Batch: 7300 | Loss: 0.61813 | Correct: 100/128
# Estimator: 004 | Epoch: 000 | Batch: 7400 | Loss: 0.51039 | Correct: 101/128
# Estimator: 004 | Epoch: 000 | Batch: 7500 | Loss: 0.60245 | Correct: 101/128
# Estimator: 004 | Epoch: 000 | Batch: 7600 | Loss: 0.47318 | Correct: 106/128
# Estimator: 004 | Epoch: 000 | Batch: 7700 | Loss: 0.63938 | Correct: 100/128
# Estimator: 004 | Epoch: 000 | Batch: 7800 | Loss: 0.39084 | Correct: 112/128
# Estimator: 004 | Epoch: 000 | Batch: 7900 | Loss: 0.66795 | Correct: 100/128
# Estimator: 004 | Epoch: 000 | Batch: 8000 | Loss: 0.47206 | Correct: 105/128
# Estimator: 004 | Epoch: 000 | Batch: 8100 | Loss: 0.57089 | Correct: 104/128
# Estimator: 004 | Epoch: 000 | Batch: 8200 | Loss: 0.60330 | Correct: 101/128
# Estimator: 004 | Epoch: 000 | Batch: 8300 | Loss: 0.64649 | Correct: 101/128
# Estimator: 004 | Epoch: 000 | Batch: 8400 | Loss: 0.67201 | Correct: 96/128
# Estimator: 004 | Epoch: 000 | Batch: 8500 | Loss: 0.53216 | Correct: 103/128
# Estimator: 004 | Epoch: 000 | Batch: 8600 | Loss: 0.52768 | Correct: 101/128
# Estimator: 005 | Epoch: 000 | Batch: 000 | Loss: 3.66438 | Correct: 3/128
# Estimator: 005 | Epoch: 000 | Batch: 100 | Loss: 1.74899 | Correct: 65/128
# Estimator: 005 | Epoch: 000 | Batch: 200 | Loss: 1.50248 | Correct: 71/128
# Estimator: 005 | Epoch: 000 | Batch: 300 | Loss: 1.38476 | Correct: 70/128
# Estimator: 005 | Epoch: 000 | Batch: 400 | Loss: 1.08611 | Correct: 86/128
# Estimator: 005 | Epoch: 000 | Batch: 500 | Loss: 1.37383 | Correct: 70/128
# Estimator: 005 | Epoch: 000 | Batch: 600 | Loss: 0.95169 | Correct: 88/128
# Estimator: 005 | Epoch: 000 | Batch: 700 | Loss: 1.12100 | Correct: 82/128
# Estimator: 005 | Epoch: 000 | Batch: 800 | Loss: 1.13432 | Correct: 84/128
# Estimator: 005 | Epoch: 000 | Batch: 900 | Loss: 0.98131 | Correct: 87/128
# Estimator: 005 | Epoch: 000 | Batch: 1000 | Loss: 1.01044 | Correct: 87/128
# Estimator: 005 | Epoch: 000 | Batch: 1100 | Loss: 0.96905 | Correct: 86/128
# Estimator: 005 | Epoch: 000 | Batch: 1200 | Loss: 1.05609 | Correct: 83/128
# Estimator: 005 | Epoch: 000 | Batch: 1300 | Loss: 1.03516 | Correct: 81/128
# Estimator: 005 | Epoch: 000 | Batch: 1400 | Loss: 1.00879 | Correct: 85/128
# Estimator: 005 | Epoch: 000 | Batch: 1500 | Loss: 1.00542 | Correct: 83/128
# Estimator: 005 | Epoch: 000 | Batch: 1600 | Loss: 0.78946 | Correct: 94/128
# Estimator: 005 | Epoch: 000 | Batch: 1700 | Loss: 0.86226 | Correct: 91/128
# Estimator: 005 | Epoch: 000 | Batch: 1800 | Loss: 0.83702 | Correct: 95/128
# Estimator: 005 | Epoch: 000 | Batch: 1900 | Loss: 0.92460 | Correct: 89/128
# Estimator: 005 | Epoch: 000 | Batch: 2000 | Loss: 1.00598 | Correct: 89/128
# Estimator: 005 | Epoch: 000 | Batch: 2100 | Loss: 1.02748 | Correct: 89/128
# Estimator: 005 | Epoch: 000 | Batch: 2200 | Loss: 0.87456 | Correct: 89/128
# Estimator: 005 | Epoch: 000 | Batch: 2300 | Loss: 0.95089 | Correct: 88/128
# Estimator: 005 | Epoch: 000 | Batch: 2400 | Loss: 0.86612 | Correct: 86/128
# Estimator: 005 | Epoch: 000 | Batch: 2500 | Loss: 0.96142 | Correct: 90/128
# Estimator: 005 | Epoch: 000 | Batch: 2600 | Loss: 0.77441 | Correct: 94/128
# Estimator: 005 | Epoch: 000 | Batch: 2700 | Loss: 0.81735 | Correct: 95/128
# Estimator: 005 | Epoch: 000 | Batch: 2800 | Loss: 0.72685 | Correct: 95/128
# Estimator: 005 | Epoch: 000 | Batch: 2900 | Loss: 0.89927 | Correct: 94/128
# Estimator: 005 | Epoch: 000 | Batch: 3000 | Loss: 0.91379 | Correct: 92/128
# Estimator: 005 | Epoch: 000 | Batch: 3100 | Loss: 0.77938 | Correct: 98/128
# Estimator: 005 | Epoch: 000 | Batch: 3200 | Loss: 0.78592 | Correct: 92/128
# Estimator: 005 | Epoch: 000 | Batch: 3300 | Loss: 0.88322 | Correct: 84/128
# Estimator: 005 | Epoch: 000 | Batch: 3400 | Loss: 0.80185 | Correct: 94/128
# Estimator: 005 | Epoch: 000 | Batch: 3500 | Loss: 0.82958 | Correct: 93/128
# Estimator: 005 | Epoch: 000 | Batch: 3600 | Loss: 0.64119 | Correct: 99/128
# Estimator: 005 | Epoch: 000 | Batch: 3700 | Loss: 0.84998 | Correct: 85/128
# Estimator: 005 | Epoch: 000 | Batch: 3800 | Loss: 0.72324 | Correct: 94/128
# Estimator: 005 | Epoch: 000 | Batch: 3900 | Loss: 0.85932 | Correct: 93/128
# Estimator: 005 | Epoch: 000 | Batch: 4000 | Loss: 0.68979 | Correct: 96/128
# Estimator: 005 | Epoch: 000 | Batch: 4100 | Loss: 0.72200 | Correct: 101/128
# Estimator: 005 | Epoch: 000 | Batch: 4200 | Loss: 0.55424 | Correct: 103/128
# Estimator: 005 | Epoch: 000 | Batch: 4300 | Loss: 0.81910 | Correct: 87/128
# Estimator: 005 | Epoch: 000 | Batch: 4400 | Loss: 0.55388 | Correct: 103/128
# Estimator: 005 | Epoch: 000 | Batch: 4500 | Loss: 0.68400 | Correct: 93/128
# Estimator: 005 | Epoch: 000 | Batch: 4600 | Loss: 0.83844 | Correct: 91/128
# Estimator: 005 | Epoch: 000 | Batch: 4700 | Loss: 0.75183 | Correct: 97/128
# Estimator: 005 | Epoch: 000 | Batch: 4800 | Loss: 0.59710 | Correct: 100/128
# Estimator: 005 | Epoch: 000 | Batch: 4900 | Loss: 0.81870 | Correct: 92/128
# Estimator: 005 | Epoch: 000 | Batch: 5000 | Loss: 0.77160 | Correct: 98/128
# Estimator: 005 | Epoch: 000 | Batch: 5100 | Loss: 0.63718 | Correct: 98/128
# Estimator: 005 | Epoch: 000 | Batch: 5200 | Loss: 0.74336 | Correct: 94/128
# Estimator: 005 | Epoch: 000 | Batch: 5300 | Loss: 0.79571 | Correct: 97/128
# Estimator: 005 | Epoch: 000 | Batch: 5400 | Loss: 0.81635 | Correct: 91/128
# Estimator: 005 | Epoch: 000 | Batch: 5500 | Loss: 0.55166 | Correct: 107/128
# Estimator: 005 | Epoch: 000 | Batch: 5600 | Loss: 0.59839 | Correct: 107/128
# Estimator: 005 | Epoch: 000 | Batch: 5700 | Loss: 0.65528 | Correct: 95/128
# Estimator: 005 | Epoch: 000 | Batch: 5800 | Loss: 0.53285 | Correct: 105/128
# Estimator: 005 | Epoch: 000 | Batch: 5900 | Loss: 0.67971 | Correct: 99/128
# Estimator: 005 | Epoch: 000 | Batch: 6000 | Loss: 0.79625 | Correct: 97/128
# Estimator: 005 | Epoch: 000 | Batch: 6100 | Loss: 0.73527 | Correct: 96/128
# Estimator: 005 | Epoch: 000 | Batch: 6200 | Loss: 0.63082 | Correct: 99/128
# Estimator: 005 | Epoch: 000 | Batch: 6300 | Loss: 0.61663 | Correct: 103/128
# Estimator: 005 | Epoch: 000 | Batch: 6400 | Loss: 0.54694 | Correct: 105/128
# Estimator: 005 | Epoch: 000 | Batch: 6500 | Loss: 0.70625 | Correct: 99/128
# Estimator: 005 | Epoch: 000 | Batch: 6600 | Loss: 0.71114 | Correct: 96/128
# Estimator: 005 | Epoch: 000 | Batch: 6700 | Loss: 0.67144 | Correct: 97/128
# Estimator: 005 | Epoch: 000 | Batch: 6800 | Loss: 0.65144 | Correct: 98/128
# Estimator: 005 | Epoch: 000 | Batch: 6900 | Loss: 0.65890 | Correct: 97/128
# Estimator: 005 | Epoch: 000 | Batch: 7000 | Loss: 0.45451 | Correct: 108/128
# Estimator: 005 | Epoch: 000 | Batch: 7100 | Loss: 0.69209 | Correct: 101/128
# Estimator: 005 | Epoch: 000 | Batch: 7200 | Loss: 0.53712 | Correct: 103/128
# Estimator: 005 | Epoch: 000 | Batch: 7300 | Loss: 0.45987 | Correct: 108/128
# Estimator: 005 | Epoch: 000 | Batch: 7400 | Loss: 0.60349 | Correct: 103/128
# Estimator: 005 | Epoch: 000 | Batch: 7500 | Loss: 0.48214 | Correct: 109/128
# Estimator: 005 | Epoch: 000 | Batch: 7600 | Loss: 0.61024 | Correct: 98/128
# Estimator: 005 | Epoch: 000 | Batch: 7700 | Loss: 0.73454 | Correct: 95/128
# Estimator: 005 | Epoch: 000 | Batch: 7800 | Loss: 0.55884 | Correct: 102/128
# Estimator: 005 | Epoch: 000 | Batch: 7900 | Loss: 0.65642 | Correct: 96/128
# Estimator: 005 | Epoch: 000 | Batch: 8000 | Loss: 0.60412 | Correct: 110/128
# Estimator: 005 | Epoch: 000 | Batch: 8100 | Loss: 0.70746 | Correct: 99/128
# Estimator: 005 | Epoch: 000 | Batch: 8200 | Loss: 0.60450 | Correct: 101/128
# Estimator: 005 | Epoch: 000 | Batch: 8300 | Loss: 0.53848 | Correct: 104/128
# Estimator: 005 | Epoch: 000 | Batch: 8400 | Loss: 0.65587 | Correct: 104/128
# Estimator: 005 | Epoch: 000 | Batch: 8500 | Loss: 0.51738 | Correct: 105/128
# Estimator: 005 | Epoch: 000 | Batch: 8600 | Loss: 0.58318 | Correct: 106/128
# Estimator: 006 | Epoch: 000 | Batch: 000 | Loss: 3.66317 | Correct: 7/128
# Estimator: 006 | Epoch: 000 | Batch: 100 | Loss: 1.49997 | Correct: 66/128
# Estimator: 006 | Epoch: 000 | Batch: 200 | Loss: 1.50266 | Correct: 69/128
# Estimator: 006 | Epoch: 000 | Batch: 300 | Loss: 1.52985 | Correct: 65/128
# Estimator: 006 | Epoch: 000 | Batch: 400 | Loss: 1.24257 | Correct: 79/128
# Estimator: 006 | Epoch: 000 | Batch: 500 | Loss: 1.16454 | Correct: 78/128
# Estimator: 006 | Epoch: 000 | Batch: 600 | Loss: 0.95028 | Correct: 85/128
# Estimator: 006 | Epoch: 000 | Batch: 700 | Loss: 1.08882 | Correct: 88/128
# Estimator: 006 | Epoch: 000 | Batch: 800 | Loss: 1.10772 | Correct: 80/128
# Estimator: 006 | Epoch: 000 | Batch: 900 | Loss: 1.08100 | Correct: 77/128
# Estimator: 006 | Epoch: 000 | Batch: 1000 | Loss: 0.96302 | Correct: 82/128
# Estimator: 006 | Epoch: 000 | Batch: 1100 | Loss: 0.89491 | Correct: 87/128
# Estimator: 006 | Epoch: 000 | Batch: 1200 | Loss: 0.96270 | Correct: 82/128
# Estimator: 006 | Epoch: 000 | Batch: 1300 | Loss: 1.01063 | Correct: 83/128
# Estimator: 006 | Epoch: 000 | Batch: 1400 | Loss: 0.81681 | Correct: 91/128
# Estimator: 006 | Epoch: 000 | Batch: 1500 | Loss: 0.89084 | Correct: 92/128
# Estimator: 006 | Epoch: 000 | Batch: 1600 | Loss: 1.09624 | Correct: 76/128
# Estimator: 006 | Epoch: 000 | Batch: 1700 | Loss: 0.98677 | Correct: 80/128
# Estimator: 006 | Epoch: 000 | Batch: 1800 | Loss: 0.98020 | Correct: 85/128
# Estimator: 006 | Epoch: 000 | Batch: 1900 | Loss: 0.85753 | Correct: 97/128
# Estimator: 006 | Epoch: 000 | Batch: 2000 | Loss: 0.75137 | Correct: 97/128
# Estimator: 006 | Epoch: 000 | Batch: 2100 | Loss: 0.77573 | Correct: 90/128
# Estimator: 006 | Epoch: 000 | Batch: 2200 | Loss: 1.06739 | Correct: 82/128
# Estimator: 006 | Epoch: 000 | Batch: 2300 | Loss: 0.91770 | Correct: 90/128
# Estimator: 006 | Epoch: 000 | Batch: 2400 | Loss: 1.08983 | Correct: 79/128
# Estimator: 006 | Epoch: 000 | Batch: 2500 | Loss: 1.00111 | Correct: 86/128
# Estimator: 006 | Epoch: 000 | Batch: 2600 | Loss: 0.99779 | Correct: 82/128
# Estimator: 006 | Epoch: 000 | Batch: 2700 | Loss: 0.81054 | Correct: 89/128
# Estimator: 006 | Epoch: 000 | Batch: 2800 | Loss: 0.72838 | Correct: 92/128
# Estimator: 006 | Epoch: 000 | Batch: 2900 | Loss: 0.90819 | Correct: 91/128
# Estimator: 006 | Epoch: 000 | Batch: 3000 | Loss: 0.80512 | Correct: 91/128
# Estimator: 006 | Epoch: 000 | Batch: 3100 | Loss: 0.79883 | Correct: 90/128
# Estimator: 006 | Epoch: 000 | Batch: 3200 | Loss: 0.88831 | Correct: 90/128
# Estimator: 006 | Epoch: 000 | Batch: 3300 | Loss: 0.64489 | Correct: 101/128
# Estimator: 006 | Epoch: 000 | Batch: 3400 | Loss: 0.76565 | Correct: 100/128
# Estimator: 006 | Epoch: 000 | Batch: 3500 | Loss: 0.77689 | Correct: 96/128
# Estimator: 006 | Epoch: 000 | Batch: 3600 | Loss: 0.67603 | Correct: 100/128
# Estimator: 006 | Epoch: 000 | Batch: 3700 | Loss: 0.68911 | Correct: 99/128
# Estimator: 006 | Epoch: 000 | Batch: 3800 | Loss: 0.85150 | Correct: 91/128
# Estimator: 006 | Epoch: 000 | Batch: 3900 | Loss: 0.70487 | Correct: 100/128
# Estimator: 006 | Epoch: 000 | Batch: 4000 | Loss: 0.83575 | Correct: 95/128
# Estimator: 006 | Epoch: 000 | Batch: 4100 | Loss: 0.67353 | Correct: 101/128
# Estimator: 006 | Epoch: 000 | Batch: 4200 | Loss: 0.76161 | Correct: 92/128
# Estimator: 006 | Epoch: 000 | Batch: 4300 | Loss: 0.56964 | Correct: 107/128
# Estimator: 006 | Epoch: 000 | Batch: 4400 | Loss: 0.65555 | Correct: 103/128
# Estimator: 006 | Epoch: 000 | Batch: 4500 | Loss: 0.82417 | Correct: 90/128
# Estimator: 006 | Epoch: 000 | Batch: 4600 | Loss: 0.65154 | Correct: 93/128
# Estimator: 006 | Epoch: 000 | Batch: 4700 | Loss: 0.71867 | Correct: 95/128
# Estimator: 006 | Epoch: 000 | Batch: 4800 | Loss: 0.75383 | Correct: 93/128
# Estimator: 006 | Epoch: 000 | Batch: 4900 | Loss: 0.62530 | Correct: 105/128
# Estimator: 006 | Epoch: 000 | Batch: 5000 | Loss: 0.72252 | Correct: 102/128
# Estimator: 006 | Epoch: 000 | Batch: 5100 | Loss: 0.63636 | Correct: 106/128
# Estimator: 006 | Epoch: 000 | Batch: 5200 | Loss: 0.75191 | Correct: 94/128
# Estimator: 006 | Epoch: 000 | Batch: 5300 | Loss: 0.63245 | Correct: 100/128
# Estimator: 006 | Epoch: 000 | Batch: 5400 | Loss: 0.52907 | Correct: 104/128
# Estimator: 006 | Epoch: 000 | Batch: 5500 | Loss: 0.77123 | Correct: 98/128
# Estimator: 006 | Epoch: 000 | Batch: 5600 | Loss: 0.61028 | Correct: 106/128
# Estimator: 006 | Epoch: 000 | Batch: 5700 | Loss: 0.56586 | Correct: 103/128
# Estimator: 006 | Epoch: 000 | Batch: 5800 | Loss: 0.63533 | Correct: 98/128
# Estimator: 006 | Epoch: 000 | Batch: 5900 | Loss: 0.59579 | Correct: 96/128
# Estimator: 006 | Epoch: 000 | Batch: 6000 | Loss: 0.62176 | Correct: 104/128
# Estimator: 006 | Epoch: 000 | Batch: 6100 | Loss: 0.61821 | Correct: 103/128
# Estimator: 006 | Epoch: 000 | Batch: 6200 | Loss: 0.46077 | Correct: 108/128
# Estimator: 006 | Epoch: 000 | Batch: 6300 | Loss: 0.56454 | Correct: 106/128
# Estimator: 006 | Epoch: 000 | Batch: 6400 | Loss: 0.65873 | Correct: 99/128
# Estimator: 006 | Epoch: 000 | Batch: 6500 | Loss: 0.78740 | Correct: 96/128
# Estimator: 006 | Epoch: 000 | Batch: 6600 | Loss: 0.62966 | Correct: 102/128
# Estimator: 006 | Epoch: 000 | Batch: 6700 | Loss: 0.53416 | Correct: 103/128
# Estimator: 006 | Epoch: 000 | Batch: 6800 | Loss: 0.84155 | Correct: 92/128
# Estimator: 006 | Epoch: 000 | Batch: 6900 | Loss: 0.53411 | Correct: 105/128
# Estimator: 006 | Epoch: 000 | Batch: 7000 | Loss: 0.78203 | Correct: 90/128
# Estimator: 006 | Epoch: 000 | Batch: 7100 | Loss: 0.57148 | Correct: 97/128
# Estimator: 006 | Epoch: 000 | Batch: 7200 | Loss: 0.56836 | Correct: 103/128
# Estimator: 006 | Epoch: 000 | Batch: 7300 | Loss: 0.58500 | Correct: 102/128
# Estimator: 006 | Epoch: 000 | Batch: 7400 | Loss: 0.74300 | Correct: 96/128
# Estimator: 006 | Epoch: 000 | Batch: 7500 | Loss: 0.55891 | Correct: 101/128
# Estimator: 006 | Epoch: 000 | Batch: 7600 | Loss: 0.54607 | Correct: 104/128
# Estimator: 006 | Epoch: 000 | Batch: 7700 | Loss: 0.54861 | Correct: 103/128
# Estimator: 006 | Epoch: 000 | Batch: 7800 | Loss: 0.61493 | Correct: 105/128
# Estimator: 006 | Epoch: 000 | Batch: 7900 | Loss: 0.51653 | Correct: 104/128
# Estimator: 006 | Epoch: 000 | Batch: 8000 | Loss: 0.50291 | Correct: 106/128
# Estimator: 006 | Epoch: 000 | Batch: 8100 | Loss: 0.52252 | Correct: 102/128
# Estimator: 006 | Epoch: 000 | Batch: 8200 | Loss: 0.37669 | Correct: 113/128
# Estimator: 006 | Epoch: 000 | Batch: 8300 | Loss: 0.55142 | Correct: 107/128
# Estimator: 006 | Epoch: 000 | Batch: 8400 | Loss: 0.43353 | Correct: 107/128
# Estimator: 006 | Epoch: 000 | Batch: 8500 | Loss: 0.44492 | Correct: 112/128
# Estimator: 006 | Epoch: 000 | Batch: 8600 | Loss: 0.58862 | Correct: 104/128
# Estimator: 007 | Epoch: 000 | Batch: 000 | Loss: 3.66374 | Correct: 2/128
# Estimator: 007 | Epoch: 000 | Batch: 100 | Loss: 1.62415 | Correct: 66/128
# Estimator: 007 | Epoch: 000 | Batch: 200 | Loss: 1.47688 | Correct: 74/128
# Estimator: 007 | Epoch: 000 | Batch: 300 | Loss: 1.16896 | Correct: 83/128
# Estimator: 007 | Epoch: 000 | Batch: 400 | Loss: 1.35744 | Correct: 78/128
# Estimator: 007 | Epoch: 000 | Batch: 500 | Loss: 1.21645 | Correct: 80/128
# Estimator: 007 | Epoch: 000 | Batch: 600 | Loss: 0.89225 | Correct: 93/128
# Estimator: 007 | Epoch: 000 | Batch: 700 | Loss: 1.22757 | Correct: 75/128
# Estimator: 007 | Epoch: 000 | Batch: 800 | Loss: 1.00503 | Correct: 81/128
# Estimator: 007 | Epoch: 000 | Batch: 900 | Loss: 1.04370 | Correct: 85/128
# Estimator: 007 | Epoch: 000 | Batch: 1000 | Loss: 0.98363 | Correct: 83/128
# Estimator: 007 | Epoch: 000 | Batch: 1100 | Loss: 0.92721 | Correct: 93/128
# Estimator: 007 | Epoch: 000 | Batch: 1200 | Loss: 0.94298 | Correct: 94/128
# Estimator: 007 | Epoch: 000 | Batch: 1300 | Loss: 0.94556 | Correct: 89/128
# Estimator: 007 | Epoch: 000 | Batch: 1400 | Loss: 1.04827 | Correct: 79/128
# Estimator: 007 | Epoch: 000 | Batch: 1500 | Loss: 1.01116 | Correct: 88/128
# Estimator: 007 | Epoch: 000 | Batch: 1600 | Loss: 0.84208 | Correct: 89/128
# Estimator: 007 | Epoch: 000 | Batch: 1700 | Loss: 0.94551 | Correct: 90/128
# Estimator: 007 | Epoch: 000 | Batch: 1800 | Loss: 0.89063 | Correct: 93/128
# ...
# Estimator: 009 | Epoch: 001 | Batch: 5500 | Loss: 0.35908 | Correct: 110/128
# Estimator: 009 | Epoch: 001 | Batch: 5600 | Loss: 0.31815 | Correct: 117/128
# Estimator: 009 | Epoch: 001 | Batch: 5700 | Loss: 0.45010 | Correct: 108/128
# Estimator: 009 | Epoch: 001 | Batch: 5800 | Loss: 0.31946 | Correct: 116/128
# Estimator: 009 | Epoch: 001 | Batch: 5900 | Loss: 0.38493 | Correct: 107/128
# Estimator: 009 | Epoch: 001 | Batch: 6000 | Loss: 0.41344 | Correct: 110/128
# Estimator: 009 | Epoch: 001 | Batch: 6100 | Loss: 0.35243 | Correct: 110/128
# Estimator: 009 | Epoch: 001 | Batch: 6200 | Loss: 0.22129 | Correct: 117/128
# Estimator: 009 | Epoch: 001 | Batch: 6300 | Loss: 0.38897 | Correct: 111/128
# Estimator: 009 | Epoch: 001 | Batch: 6400 | Loss: 0.27414 | Correct: 119/128
# Estimator: 009 | Epoch: 001 | Batch: 6500 | Loss: 0.33004 | Correct: 108/128
# Estimator: 009 | Epoch: 001 | Batch: 6600 | Loss: 0.41127 | Correct: 109/128
# Estimator: 009 | Epoch: 001 | Batch: 6700 | Loss: 0.28617 | Correct: 117/128
# Estimator: 009 | Epoch: 001 | Batch: 6800 | Loss: 0.37227 | Correct: 111/128
# Estimator: 009 | Epoch: 001 | Batch: 6900 | Loss: 0.46820 | Correct: 107/128
# Estimator: 009 | Epoch: 001 | Batch: 7000 | Loss: 0.29051 | Correct: 113/128
# Estimator: 009 | Epoch: 001 | Batch: 7100 | Loss: 0.30552 | Correct: 114/128
# Estimator: 009 | Epoch: 001 | Batch: 7200 | Loss: 0.27331 | Correct: 115/128
# Estimator: 009 | Epoch: 001 | Batch: 7300 | Loss: 0.30193 | Correct: 114/128
# Estimator: 009 | Epoch: 001 | Batch: 7400 | Loss: 0.20516 | Correct: 121/128
# Estimator: 009 | Epoch: 001 | Batch: 7500 | Loss: 0.28723 | Correct: 118/128
# Estimator: 009 | Epoch: 001 | Batch: 7600 | Loss: 0.29709 | Correct: 113/128
# Estimator: 009 | Epoch: 001 | Batch: 7700 | Loss: 0.21912 | Correct: 116/128
# Estimator: 009 | Epoch: 001 | Batch: 7800 | Loss: 0.26260 | Correct: 114/128
# Estimator: 009 | Epoch: 001 | Batch: 7900 | Loss: 0.37955 | Correct: 111/128
# Estimator: 009 | Epoch: 001 | Batch: 8000 | Loss: 0.25263 | Correct: 114/128
# Estimator: 009 | Epoch: 001 | Batch: 8100 | Loss: 0.36737 | Correct: 114/128
# Estimator: 009 | Epoch: 001 | Batch: 8200 | Loss: 0.32086 | Correct: 114/128
# Estimator: 009 | Epoch: 001 | Batch: 8300 | Loss: 0.28531 | Correct: 114/128
# Estimator: 009 | Epoch: 001 | Batch: 8400 | Loss: 0.46630 | Correct: 106/128
# Estimator: 009 | Epoch: 001 | Batch: 8500 | Loss: 0.31429 | Correct: 117/128
# Estimator: 009 | Epoch: 001 | Batch: 8600 | Loss: 0.39910 | Correct: 110/128
# Estimator: 010 | Epoch: 001 | Batch: 000 | Loss: 0.48998 | Correct: 106/128
# Estimator: 010 | Epoch: 001 | Batch: 100 | Loss: 0.38269 | Correct: 114/128
# Estimator: 010 | Epoch: 001 | Batch: 200 | Loss: 0.35833 | Correct: 113/128
# Estimator: 010 | Epoch: 001 | Batch: 300 | Loss: 0.27888 | Correct: 116/128
# Estimator: 010 | Epoch: 001 | Batch: 400 | Loss: 0.45622 | Correct: 110/128
# Estimator: 010 | Epoch: 001 | Batch: 500 | Loss: 0.50739 | Correct: 110/128
# Estimator: 010 | Epoch: 001 | Batch: 600 | Loss: 0.53715 | Correct: 102/128
# Estimator: 010 | Epoch: 001 | Batch: 700 | Loss: 0.61311 | Correct: 99/128
# Estimator: 010 | Epoch: 001 | Batch: 800 | Loss: 0.35094 | Correct: 110/128
# Estimator: 010 | Epoch: 001 | Batch: 900 | Loss: 0.61610 | Correct: 103/128
# Estimator: 010 | Epoch: 001 | Batch: 1000 | Loss: 0.36101 | Correct: 113/128
# Estimator: 010 | Epoch: 001 | Batch: 1100 | Loss: 0.43256 | Correct: 113/128
# Estimator: 010 | Epoch: 001 | Batch: 1200 | Loss: 0.42525 | Correct: 110/128
# Estimator: 010 | Epoch: 001 | Batch: 1300 | Loss: 0.71767 | Correct: 96/128
# Estimator: 010 | Epoch: 001 | Batch: 1400 | Loss: 0.36718 | Correct: 112/128
# Estimator: 010 | Epoch: 001 | Batch: 1500 | Loss: 0.46423 | Correct: 111/128
# Estimator: 010 | Epoch: 001 | Batch: 1600 | Loss: 0.47130 | Correct: 107/128
# Estimator: 010 | Epoch: 001 | Batch: 1700 | Loss: 0.46680 | Correct: 109/128
# Estimator: 010 | Epoch: 001 | Batch: 1800 | Loss: 0.38266 | Correct: 111/128
# Estimator: 010 | Epoch: 001 | Batch: 1900 | Loss: 0.50304 | Correct: 102/128
# Estimator: 010 | Epoch: 001 | Batch: 2000 | Loss: 0.58411 | Correct: 104/128
# Estimator: 010 | Epoch: 001 | Batch: 2100 | Loss: 0.40260 | Correct: 110/128
# Estimator: 010 | Epoch: 001 | Batch: 2200 | Loss: 0.45054 | Correct: 108/128
# Estimator: 010 | Epoch: 001 | Batch: 2300 | Loss: 0.50192 | Correct: 104/128
# Estimator: 010 | Epoch: 001 | Batch: 2400 | Loss: 0.49410 | Correct: 107/128
# Estimator: 010 | Epoch: 001 | Batch: 2500 | Loss: 0.53269 | Correct: 103/128
# Estimator: 010 | Epoch: 001 | Batch: 2600 | Loss: 0.27667 | Correct: 116/128
# Estimator: 010 | Epoch: 001 | Batch: 2700 | Loss: 0.39581 | Correct: 109/128
# Estimator: 010 | Epoch: 001 | Batch: 2800 | Loss: 0.40735 | Correct: 109/128
# Estimator: 010 | Epoch: 001 | Batch: 2900 | Loss: 0.31523 | Correct: 116/128
# Estimator: 010 | Epoch: 001 | Batch: 3000 | Loss: 0.37729 | Correct: 110/128
# Estimator: 010 | Epoch: 001 | Batch: 3100 | Loss: 0.34560 | Correct: 111/128
# Estimator: 010 | Epoch: 001 | Batch: 3200 | Loss: 0.43150 | Correct: 106/128
# Estimator: 010 | Epoch: 001 | Batch: 3300 | Loss: 0.47595 | Correct: 108/128
# Estimator: 010 | Epoch: 001 | Batch: 3400 | Loss: 0.40963 | Correct: 108/128
# Estimator: 010 | Epoch: 001 | Batch: 3500 | Loss: 0.26581 | Correct: 117/128
# Estimator: 010 | Epoch: 001 | Batch: 3600 | Loss: 0.48146 | Correct: 103/128
# Estimator: 010 | Epoch: 001 | Batch: 3700 | Loss: 0.45025 | Correct: 109/128
# Estimator: 010 | Epoch: 001 | Batch: 3800 | Loss: 0.27962 | Correct: 115/128
# Estimator: 010 | Epoch: 001 | Batch: 3900 | Loss: 0.45125 | Correct: 107/128
# Estimator: 010 | Epoch: 001 | Batch: 4000 | Loss: 0.44352 | Correct: 107/128
# Estimator: 010 | Epoch: 001 | Batch: 4100 | Loss: 0.54903 | Correct: 110/128
# Estimator: 010 | Epoch: 001 | Batch: 4200 | Loss: 0.30253 | Correct: 116/128
# Estimator: 010 | Epoch: 001 | Batch: 4300 | Loss: 0.32283 | Correct: 113/128
# Estimator: 010 | Epoch: 001 | Batch: 4400 | Loss: 0.39322 | Correct: 110/128
# Estimator: 010 | Epoch: 001 | Batch: 4500 | Loss: 0.41505 | Correct: 110/128
# Estimator: 010 | Epoch: 001 | Batch: 4600 | Loss: 0.28135 | Correct: 114/128
# Estimator: 010 | Epoch: 001 | Batch: 4700 | Loss: 0.43015 | Correct: 107/128
# Estimator: 010 | Epoch: 001 | Batch: 4800 | Loss: 0.34243 | Correct: 117/128
# Estimator: 010 | Epoch: 001 | Batch: 4900 | Loss: 0.28843 | Correct: 114/128
# Estimator: 010 | Epoch: 001 | Batch: 5000 | Loss: 0.29985 | Correct: 114/128
# Estimator: 010 | Epoch: 001 | Batch: 5100 | Loss: 0.32221 | Correct: 114/128
# Estimator: 010 | Epoch: 001 | Batch: 5200 | Loss: 0.38719 | Correct: 113/128
# Estimator: 010 | Epoch: 001 | Batch: 5300 | Loss: 0.31761 | Correct: 112/128
# Estimator: 010 | Epoch: 001 | Batch: 5400 | Loss: 0.33954 | Correct: 113/128
# Estimator: 010 | Epoch: 001 | Batch: 5500 | Loss: 0.27715 | Correct: 120/128
# Estimator: 010 | Epoch: 001 | Batch: 5600 | Loss: 0.40025 | Correct: 109/128
# Estimator: 010 | Epoch: 001 | Batch: 5700 | Loss: 0.43155 | Correct: 108/128
# Estimator: 010 | Epoch: 001 | Batch: 5800 | Loss: 0.31581 | Correct: 114/128
# Estimator: 010 | Epoch: 001 | Batch: 5900 | Loss: 0.38737 | Correct: 108/128
# Estimator: 010 | Epoch: 001 | Batch: 6000 | Loss: 0.23575 | Correct: 114/128
# Estimator: 010 | Epoch: 001 | Batch: 6100 | Loss: 0.37832 | Correct: 110/128
# Estimator: 010 | Epoch: 001 | Batch: 6200 | Loss: 0.38582 | Correct: 108/128
# Estimator: 010 | Epoch: 001 | Batch: 6300 | Loss: 0.39333 | Correct: 109/128
# Estimator: 010 | Epoch: 001 | Batch: 6400 | Loss: 0.38006 | Correct: 113/128
# Estimator: 010 | Epoch: 001 | Batch: 6500 | Loss: 0.31755 | Correct: 114/128
# Estimator: 010 | Epoch: 001 | Batch: 6600 | Loss: 0.40120 | Correct: 110/128
# Estimator: 010 | Epoch: 001 | Batch: 6700 | Loss: 0.34607 | Correct: 111/128
# Estimator: 010 | Epoch: 001 | Batch: 6800 | Loss: 0.34459 | Correct: 113/128
# Estimator: 010 | Epoch: 001 | Batch: 6900 | Loss: 0.29440 | Correct: 109/128
# Estimator: 010 | Epoch: 001 | Batch: 7000 | Loss: 0.35646 | Correct: 113/128
# Estimator: 010 | Epoch: 001 | Batch: 7100 | Loss: 0.43641 | Correct: 103/128
# Estimator: 010 | Epoch: 001 | Batch: 7200 | Loss: 0.24459 | Correct: 115/128
# Estimator: 010 | Epoch: 001 | Batch: 7300 | Loss: 0.31966 | Correct: 115/128
# Estimator: 010 | Epoch: 001 | Batch: 7400 | Loss: 0.40605 | Correct: 112/128
# Estimator: 010 | Epoch: 001 | Batch: 7500 | Loss: 0.31398 | Correct: 113/128
# Estimator: 010 | Epoch: 001 | Batch: 7600 | Loss: 0.33160 | Correct: 115/128
# Estimator: 010 | Epoch: 001 | Batch: 7700 | Loss: 0.32495 | Correct: 112/128
# Estimator: 010 | Epoch: 001 | Batch: 7800 | Loss: 0.34312 | Correct: 114/128
# Estimator: 010 | Epoch: 001 | Batch: 7900 | Loss: 0.36897 | Correct: 111/128
# Estimator: 010 | Epoch: 001 | Batch: 8000 | Loss: 0.29612 | Correct: 117/128
# Estimator: 010 | Epoch: 001 | Batch: 8100 | Loss: 0.42680 | Correct: 110/128
# Estimator: 010 | Epoch: 001 | Batch: 8200 | Loss: 0.29518 | Correct: 111/128
# Estimator: 010 | Epoch: 001 | Batch: 8300 | Loss: 0.20728 | Correct: 119/128
# Estimator: 010 | Epoch: 001 | Batch: 8400 | Loss: 0.46117 | Correct: 105/128
# Estimator: 010 | Epoch: 001 | Batch: 8500 | Loss: 0.35587 | Correct: 114/128
# Estimator: 010 | Epoch: 001 | Batch: 8600 | Loss: 0.42745 | Correct: 111/128
# Estimator: 011 | Epoch: 001 | Batch: 000 | Loss: 0.43632 | Correct: 111/128
# Estimator: 011 | Epoch: 001 | Batch: 100 | Loss: 0.39045 | Correct: 111/128
# Estimator: 011 | Epoch: 001 | Batch: 200 | Loss: 0.45199 | Correct: 109/128
# Estimator: 011 | Epoch: 001 | Batch: 300 | Loss: 0.50251 | Correct: 106/128
# Estimator: 011 | Epoch: 001 | Batch: 400 | Loss: 0.42830 | Correct: 112/128
# Estimator: 011 | Epoch: 001 | Batch: 500 | Loss: 0.34633 | Correct: 112/128
# Estimator: 011 | Epoch: 001 | Batch: 600 | Loss: 0.48407 | Correct: 108/128
# Estimator: 011 | Epoch: 001 | Batch: 700 | Loss: 0.43353 | Correct: 110/128
# Estimator: 011 | Epoch: 001 | Batch: 800 | Loss: 0.44086 | Correct: 107/128
# Estimator: 011 | Epoch: 001 | Batch: 900 | Loss: 0.42412 | Correct: 110/128
# Estimator: 011 | Epoch: 001 | Batch: 1000 | Loss: 0.37914 | Correct: 110/128
# Estimator: 011 | Epoch: 001 | Batch: 1100 | Loss: 0.37592 | Correct: 115/128
# Estimator: 011 | Epoch: 001 | Batch: 1200 | Loss: 0.48966 | Correct: 109/128
# Estimator: 011 | Epoch: 001 | Batch: 1300 | Loss: 0.39901 | Correct: 112/128
# Estimator: 011 | Epoch: 001 | Batch: 1400 | Loss: 0.40109 | Correct: 111/128
# Estimator: 011 | Epoch: 001 | Batch: 1500 | Loss: 0.41877 | Correct: 106/128
# Estimator: 011 | Epoch: 001 | Batch: 1600 | Loss: 0.39857 | Correct: 109/128
# Estimator: 011 | Epoch: 001 | Batch: 1700 | Loss: 0.50671 | Correct: 102/128
# Estimator: 011 | Epoch: 001 | Batch: 1800 | Loss: 0.46713 | Correct: 103/128
# Estimator: 011 | Epoch: 001 | Batch: 1900 | Loss: 0.36073 | Correct: 113/128
# Estimator: 011 | Epoch: 001 | Batch: 2000 | Loss: 0.53441 | Correct: 103/128
# Estimator: 011 | Epoch: 001 | Batch: 2100 | Loss: 0.37099 | Correct: 109/128
# Estimator: 011 | Epoch: 001 | Batch: 2200 | Loss: 0.36217 | Correct: 113/128
# Estimator: 011 | Epoch: 001 | Batch: 2300 | Loss: 0.48841 | Correct: 106/128
# Estimator: 011 | Epoch: 001 | Batch: 2400 | Loss: 0.23881 | Correct: 119/128
# Estimator: 011 | Epoch: 001 | Batch: 2500 | Loss: 0.50630 | Correct: 107/128
# Estimator: 011 | Epoch: 001 | Batch: 2600 | Loss: 0.33007 | Correct: 115/128
# Estimator: 011 | Epoch: 001 | Batch: 2700 | Loss: 0.38495 | Correct: 108/128
# Estimator: 011 | Epoch: 001 | Batch: 2800 | Loss: 0.45981 | Correct: 105/128
# Estimator: 011 | Epoch: 001 | Batch: 2900 | Loss: 0.43109 | Correct: 111/128
# Estimator: 011 | Epoch: 001 | Batch: 3000 | Loss: 0.44672 | Correct: 110/128
# Estimator: 011 | Epoch: 001 | Batch: 3100 | Loss: 0.47410 | Correct: 105/128
# Estimator: 011 | Epoch: 001 | Batch: 3200 | Loss: 0.48426 | Correct: 108/128
# Estimator: 011 | Epoch: 001 | Batch: 3300 | Loss: 0.25603 | Correct: 117/128
# Estimator: 011 | Epoch: 001 | Batch: 3400 | Loss: 0.32636 | Correct: 112/128
# Estimator: 011 | Epoch: 001 | Batch: 3500 | Loss: 0.47613 | Correct: 107/128
# Estimator: 011 | Epoch: 001 | Batch: 3600 | Loss: 0.29174 | Correct: 115/128
# Estimator: 011 | Epoch: 001 | Batch: 3700 | Loss: 0.29101 | Correct: 116/128
# Estimator: 011 | Epoch: 001 | Batch: 3800 | Loss: 0.40593 | Correct: 106/128
# Estimator: 011 | Epoch: 001 | Batch: 3900 | Loss: 0.36720 | Correct: 109/128
# Estimator: 011 | Epoch: 001 | Batch: 4000 | Loss: 0.38086 | Correct: 111/128
# Estimator: 011 | Epoch: 001 | Batch: 4100 | Loss: 0.32681 | Correct: 114/128
# Estimator: 011 | Epoch: 001 | Batch: 4200 | Loss: 0.40413 | Correct: 106/128
# Estimator: 011 | Epoch: 001 | Batch: 4300 | Loss: 0.37963 | Correct: 108/128
# Estimator: 011 | Epoch: 001 | Batch: 4400 | Loss: 0.35937 | Correct: 112/128
# Estimator: 011 | Epoch: 001 | Batch: 4500 | Loss: 0.39385 | Correct: 108/128
# Estimator: 011 | Epoch: 001 | Batch: 4600 | Loss: 0.30409 | Correct: 114/128
# Estimator: 011 | Epoch: 001 | Batch: 4700 | Loss: 0.32646 | Correct: 113/128
# Estimator: 011 | Epoch: 001 | Batch: 4800 | Loss: 0.33037 | Correct: 113/128
# Estimator: 011 | Epoch: 001 | Batch: 4900 | Loss: 0.30678 | Correct: 116/128
# Estimator: 011 | Epoch: 001 | Batch: 5000 | Loss: 0.42138 | Correct: 106/128
# Estimator: 011 | Epoch: 001 | Batch: 5100 | Loss: 0.17228 | Correct: 121/128
# Estimator: 011 | Epoch: 001 | Batch: 5200 | Loss: 0.27176 | Correct: 117/128
# Estimator: 011 | Epoch: 001 | Batch: 5300 | Loss: 0.26813 | Correct: 115/128
# Estimator: 011 | Epoch: 001 | Batch: 5400 | Loss: 0.29203 | Correct: 115/128
# Estimator: 011 | Epoch: 001 | Batch: 5500 | Loss: 0.32045 | Correct: 111/128
# Estimator: 011 | Epoch: 001 | Batch: 5600 | Loss: 0.36874 | Correct: 110/128
# Estimator: 011 | Epoch: 001 | Batch: 5700 | Loss: 0.30161 | Correct: 117/128
# Estimator: 011 | Epoch: 001 | Batch: 5800 | Loss: 0.41112 | Correct: 108/128
# Estimator: 011 | Epoch: 001 | Batch: 5900 | Loss: 0.28628 | Correct: 115/128
# Estimator: 011 | Epoch: 001 | Batch: 6000 | Loss: 0.57642 | Correct: 106/128
# Estimator: 011 | Epoch: 001 | Batch: 6100 | Loss: 0.37875 | Correct: 111/128
# Estimator: 011 | Epoch: 001 | Batch: 6200 | Loss: 0.37500 | Correct: 110/128
# Estimator: 011 | Epoch: 001 | Batch: 6300 | Loss: 0.36270 | Correct: 112/128
# Estimator: 011 | Epoch: 001 | Batch: 6400 | Loss: 0.28973 | Correct: 111/128
# Estimator: 011 | Epoch: 001 | Batch: 6500 | Loss: 0.41956 | Correct: 111/128
# Estimator: 011 | Epoch: 001 | Batch: 6600 | Loss: 0.30034 | Correct: 115/128
# Estimator: 011 | Epoch: 001 | Batch: 6700 | Loss: 0.31917 | Correct: 116/128
# Estimator: 011 | Epoch: 001 | Batch: 6800 | Loss: 0.42486 | Correct: 108/128
# Estimator: 011 | Epoch: 001 | Batch: 6900 | Loss: 0.30394 | Correct: 111/128
# Estimator: 011 | Epoch: 001 | Batch: 7000 | Loss: 0.53322 | Correct: 103/128
# Estimator: 011 | Epoch: 001 | Batch: 7100 | Loss: 0.31149 | Correct: 115/128
# Estimator: 011 | Epoch: 001 | Batch: 7200 | Loss: 0.44535 | Correct: 110/128
# Estimator: 011 | Epoch: 001 | Batch: 7300 | Loss: 0.27033 | Correct: 115/128
# Estimator: 011 | Epoch: 001 | Batch: 7400 | Loss: 0.24315 | Correct: 116/128
# Estimator: 011 | Epoch: 001 | Batch: 7500 | Loss: 0.29706 | Correct: 115/128
# Estimator: 011 | Epoch: 001 | Batch: 7600 | Loss: 0.29890 | Correct: 114/128
# Estimator: 011 | Epoch: 001 | Batch: 7700 | Loss: 0.41179 | Correct: 112/128
# Estimator: 011 | Epoch: 001 | Batch: 7800 | Loss: 0.38226 | Correct: 108/128
# Estimator: 011 | Epoch: 001 | Batch: 7900 | Loss: 0.25736 | Correct: 116/128
# Estimator: 011 | Epoch: 001 | Batch: 8000 | Loss: 0.33565 | Correct: 113/128
# Estimator: 011 | Epoch: 001 | Batch: 8100 | Loss: 0.39641 | Correct: 106/128
# Estimator: 011 | Epoch: 001 | Batch: 8200 | Loss: 0.37354 | Correct: 113/128
# Estimator: 011 | Epoch: 001 | Batch: 8300 | Loss: 0.32017 | Correct: 112/128
# Estimator: 011 | Epoch: 001 | Batch: 8400 | Loss: 0.26499 | Correct: 117/128
# Estimator: 011 | Epoch: 001 | Batch: 8500 | Loss: 0.24926 | Correct: 116/128
# Estimator: 011 | Epoch: 001 | Batch: 8600 | Loss: 0.41766 | Correct: 111/128
# 2021-04-01 18:08:55,335 - INFO: Epoch: 001 | Validation Acc: 77.331 % | Historical Best: 77.466 %

# %% [markdown]
# ## Testing

# %% [markdown]
# Create a testing dataset, and load model from the saved checkpoint.

# %%
# create testing dataset
test_set = TIMITDataset(test, None)
test_loader = DataLoader(test_set, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Make prediction.

# %%
predict = []
model.eval() # set the model to evaluation mode
with torch.no_grad():
    for i, data in enumerate(test_loader):
        inputs = data
        inputs = inputs.to(device)
        outputs = model(inputs)
        _, test_pred = torch.max(outputs, 1) # get the index of the class with the highest probability

        for y in test_pred.cpu().numpy():
            predict.append(y)

# %% [markdown]
# Write prediction to a CSV file.
#
# After finish running this block, download the file `prediction.csv` from the files section on the left-hand side and submit it to Kaggle.

# %%
with open('prediction.csv', 'w') as f:
    f.write('Id,Class\n')
    for i, y in enumerate(predict):
        if i < len(predict) - 1 and i > 0: # post processing
            if (predict[i-1] == predict[i+1] and y != predict[i-1]):
                y = predict[i-1]
            if (predict[i-1] != predict[i+1] and y != predict[i-1] and y != predict[i+1]):
                y = predict[i-1]
        f.write('{},{}\n'.format(i, y))
